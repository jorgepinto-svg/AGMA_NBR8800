# %%
import pandas as pd
import numpy as np

# Passo 1: Abrir e ler o arquivo Excel dados_exportados_final.xlsx
file_path = 'dados_exportados_final.xlsx'
df = pd.read_excel(file_path, header=None)

# Passo 2: Definir as colunas a partir da primeira linha
df.columns = df.iloc[0]  # A primeira linha é o cabeçalho
df = df.drop(0)  # Remover a primeira linha (já usada como cabeçalho)

# Passo 3: Tentar localizar as colunas e lidar com erros
try:
    # Aqui, você pode acessar diretamente os índices das colunas no DataFrame usando os nomes das colunas.
    idx_Frame = df.columns.get_loc("Frame") 
    idx_Station = df.columns.get_loc("Station")
    idx_OutputCase = df.columns.get_loc("OutputCase")  
    idx_CaseType = df.columns.get_loc("CaseType")
    idx_P = df.columns.get_loc("P")
    idx_V2 = df.columns.get_loc("V2")
    idx_V3 = df.columns.get_loc("V3")
    idx_T = df.columns.get_loc("T")
    idx_M2 = df.columns.get_loc("M2")
    idx_M3 = df.columns.get_loc("M3")
    idx_SectionType = df.columns.get_loc("SectionType")
    idx_SectionName = df.columns.get_loc("SectionName")
    idx_Material = df.columns.get_loc("Material")
    idx_Shape = df.columns.get_loc("Shape")
    idx_t3 = df.columns.get_loc("t3")
    idx_t2 = df.columns.get_loc("t2")
    idx_tf = df.columns.get_loc("tf")
    idx_tw = df.columns.get_loc("tw")
    idx_t2b = df.columns.get_loc("t2b")
    idx_tfb = df.columns.get_loc("tfb")
    idx_FilletRadius = df.columns.get_loc("FilletRadius")
    idx_Area = df.columns.get_loc("Area")
    idx_TorsConst = df.columns.get_loc("TorsConst")
    idx_I33 = df.columns.get_loc("I33")
    idx_I22 = df.columns.get_loc("I22")
    idx_I23 = df.columns.get_loc("I23")
    idx_AS2 = df.columns.get_loc("AS2")
    idx_AS3 = df.columns.get_loc("AS3")
    idx_S33 = df.columns.get_loc("S33")
    idx_S22 = df.columns.get_loc("S22")
    idx_Z33 = df.columns.get_loc("Z33")
    idx_Z22 = df.columns.get_loc("Z22")
    idx_R33 = df.columns.get_loc("R33")
    idx_R22 = df.columns.get_loc("R22")
    idx_TotalWt = df.columns.get_loc("TotalWt")
    idx_TotalMass = df.columns.get_loc("TotalMass")
    idx_Notes = df.columns.get_loc("Notes")
    idx_E1 = df.columns.get_loc("E1")
    idx_G12 = df.columns.get_loc("G12")
    idx_U12 = df.columns.get_loc("U12")
    idx_A1 = df.columns.get_loc("A1")
    idx_Fy_x = df.columns.get_loc("Fy_x")
    idx_Fu = df.columns.get_loc("Fu")
    idx_DesignSect = df.columns.get_loc("DesignSect")
    idx_Combo = df.columns.get_loc("Combo")
    idx_XLMajor = df.columns.get_loc("XLMajor")
    idx_XLMinor = df.columns.get_loc("XLMinor")
    idx_Length = df.columns.get_loc("Length")
    idx_gamma_a1 = df.columns.get_loc("gamma_a1")
    idx_gamma_a2 = df.columns.get_loc("gamma_a2")
    idx_r_0 = df.columns.get_loc("r_0")
    idx_C_w = df.columns.get_loc("C_w")
    idx_N_ex = df.columns.get_loc("N_ex")
    idx_N_ey = df.columns.get_loc("N_ey")
    idx_XL_z = df.columns.get_loc("XL_z")
    idx_N_ez = df.columns.get_loc("N_ez")
    idx_N_ec = df.columns.get_loc("N_ec")
    idx_N_et_1 = df.columns.get_loc("N_et_1")
    idx_N_et_2 = df.columns.get_loc("N_et_2")
    idx_N_t_Rd = df.columns.get_loc("N_t_Rd")
    idx_bt_lim_inf_grupo_02 = df.columns.get_loc("bt_lim_inf_grupo_02")
    idx_bt_lim_inf_grupo_04 = df.columns.get_loc("bt_lim_inf_grupo_04")
    idx_lambda_0  = df.columns.get_loc("lambda_0")
    idx_chi = df.columns.get_loc("chi")
    idx_sigma_el_alma = df.columns.get_loc("sigma_el_alma")
    idx_sigma_el_mesa_sup = df.columns.get_loc("sigma_el_mesa_sup")
    idx_sigma_el_mesa_inf = df.columns.get_loc("sigma_el_mesa_inf")
    idx_teste_sigma_el_alma = df.columns.get_loc("teste_sigma_el_alma")
    idx_teste_sigma_el_mesa_sup = df.columns.get_loc("teste_sigma_el_mesa_sup")
    idx_teste_sigma_el_mesa_inf = df.columns.get_loc("teste_sigma_el_mesa_inf")
    idx_compacto = df.columns.get_loc("compacto")
    idx_b_ef_alma = df.columns.get_loc("b_ef_alma")
    idx_b_ef_mesa_sup = df.columns.get_loc("b_ef_mesa_sup")
    idx_b_ef_mesa_inf = df.columns.get_loc("b_ef_mesa_inf")
    idx_Area_ef  = df.columns.get_loc("Area_ef")
    idx_N_c_Rd = df.columns.get_loc("N_c_Rd")
    idx_N_Rd = df.columns.get_loc("N_Rd")
    idx_C_b  = df.columns.get_loc("C_b")
    idx_y_c = df.columns.get_loc("y_c")
    idx_beta_1 = df.columns.get_loc("beta_1")
    idx_I_x_sup = df.columns.get_loc("I_x_sup")
    idx_I_x_inf = df.columns.get_loc("I_x_inf")
    idx_Area_x_sup = df.columns.get_loc("Area_x_sup")
    idx_Area_x_inf = df.columns.get_loc("Area_x_inf")
    idx_r_x_sup = df.columns.get_loc("r_x_sup")
    idx_r_x_inf = df.columns.get_loc("r_x_inf")
    idx_W_x_sup = df.columns.get_loc("W_x_sup")
    idx_W_x_inf = df.columns.get_loc("W_x_inf")
    idx_W_x_c = df.columns.get_loc("W_x_c")
    idx_W_x_t = df.columns.get_loc("W_x_t")
    idx_I_y_esq = df.columns.get_loc("I_y_esq")
    idx_I_y_dir = df.columns.get_loc("I_y_dir")
    idx_Area_y_esq = df.columns.get_loc("Area_y_esq")
    idx_Area_y_dir = df.columns.get_loc("Area_y_dir")
    idx_r_y_esq = df.columns.get_loc("r_y_esq")
    idx_r_y_dir = df.columns.get_loc("r_y_dir")
    idx_W_y_esq = df.columns.get_loc("W_y_esq")
    idx_W_y_dir = df.columns.get_loc("W_y_dir")
    idx_W_y_c = df.columns.get_loc("W_y_c")
    idx_W_y_t = df.columns.get_loc("W_y_t")
    idx_M_r_tipo_1_FLT = df.columns.get_loc("M_r_tipo_1_FLT")
    idx_M_cr_tipo_1_FLT = df.columns.get_loc("M_cr_tipo_1_FLT")
    idx_lambda_tipo_1_FLT = df.columns.get_loc("lambda_tipo_1_FLT")
    idx_lambda_p_tipo_1_FLT = df.columns.get_loc("lambda_p_tipo_1_FLT")
    idx_lambda_r_tipo_1_FLT = df.columns.get_loc("lambda_r_tipo_1_FLT")
    idx_M_pl_tipo_1_FLT = df.columns.get_loc("M_pl_tipo_1_FLT")
    idx_M_r_tipo_1_FLM = df.columns.get_loc("M_r_tipo_1_FLM")
    idx_M_cr_tipo_1_FLM = df.columns.get_loc("M_cr_tipo_1_FLM")
    idx_lambda_tipo_1_FLM = df.columns.get_loc("lambda_tipo_1_FLM")
    idx_lambda_p_tipo_1_FLM = df.columns.get_loc("lambda_p_tipo_1_FLM")
    idx_lambda_r_tipo_1_FLM = df.columns.get_loc("lambda_r_tipo_1_FLM")
    idx_M_pl_tipo_1_FLM = df.columns.get_loc("M_pl_tipo_1_FLM")
    idx_M_r_tipo_1_FLA = df.columns.get_loc("M_r_tipo_1_FLA")
    idx_M_cr_tipo_1_FLA = df.columns.get_loc("M_cr_tipo_1_FLA")
    idx_lambda_tipo_1_FLA = df.columns.get_loc("lambda_tipo_1_FLA")
    idx_lambda_p_tipo_1_FLA = df.columns.get_loc("lambda_p_tipo_1_FLA")
    idx_lambda_r_tipo_1_FLA = df.columns.get_loc("lambda_r_tipo_1_FLA")
    idx_M_pl_tipo_1_FLA = df.columns.get_loc("M_pl_tipo_1_FLA")
    idx_M_r_tipo_3_FLM = df.columns.get_loc("M_r_tipo_3_FLM")
    idx_M_cr_tipo_3_FLM = df.columns.get_loc("M_cr_tipo_3_FLM")
    idx_lambda_tipo_3_FLM = df.columns.get_loc("lambda_tipo_3_FLM")
    idx_lambda_p_tipo_3_FLM = df.columns.get_loc("lambda_p_tipo_3_FLM")
    idx_lambda_r_tipo_3_FLM = df.columns.get_loc("lambda_r_tipo_3_FLM")
    idx_M_pl_tipo_3_FLM = df.columns.get_loc("M_pl_tipo_3_FLM")
    idx_M_Rd_tipo_1_FLT = df.columns.get_loc("M_Rd_tipo_1_FLT")
    idx_M_Rd_tipo_1_FLM = df.columns.get_loc("M_Rd_tipo_1_FLM")
    idx_M_Rd_tipo_1_FLA = df.columns.get_loc("M_Rd_tipo_1_FLA")
    idx_M_Rd_tipo_1 = df.columns.get_loc("M_Rd_tipo_1")
    idx_M_Rd_tipo_3_FLM = df.columns.get_loc("M_Rd_tipo_3_FLM")
    idx_M_Rd_tipo_3 = df.columns.get_loc("M_Rd_tipo_3")
    idx_V_pl_vert = df.columns.get_loc("V_pl_vert")
    idx_k_v_vert = df.columns.get_loc("k_v_vert")
    idx_lambda_V_Rd_vert = df.columns.get_loc("lambda_V_Rd_vert")
    idx_lambda_p_V_Rd_vert = df.columns.get_loc("lambda_p_V_Rd_vert")
    idx_lambda_r_V_Rd_vert = df.columns.get_loc("lambda_r_V_Rd_vert")
    idx_V_Rd_vert = df.columns.get_loc("V_Rd_vert")
    idx_V_Sd_V_Rd_vert = df.columns.get_loc("V_Sd_V_Rd_vert")
    idx_V_pl_horz = df.columns.get_loc("V_pl_horz")
    idx_k_v_horz = df.columns.get_loc("k_v_horz")
    idx_lambda_V_Rd_horz = df.columns.get_loc("lambda_V_Rd_horz")
    idx_lambda_p_V_Rd_horz = df.columns.get_loc("lambda_p_V_Rd_horz")
    idx_lambda_r_V_Rd_horz = df.columns.get_loc("lambda_r_V_Rd_horz")
    idx_V_Rd_horz = df.columns.get_loc("V_Rd_horz")
    idx_V_Sd_V_Rd_horz = df.columns.get_loc("V_Sd_V_Rd_horz")
    idx_N_Sd_N_Rd = df.columns.get_loc("N_Sd_N_Rd")
    idx_M_xSd_M_xRd = df.columns.get_loc("M_xSd_M_xRd")
    idx_M_ySd_M_yRd = df.columns.get_loc("M_ySd_M_yRd")
    idx_item_nota = df.columns.get_loc("item_nota")
    idx_Verificação_PMM = df.columns.get_loc("Verificação_PMM")

except KeyError as e:
    print(f"Erro: Coluna não encontrada - {e}")     # Ou faça outra ação para tratar o erro, se necessário

# %%
while True:
    # Passo 2: Perguntar ao usuário qual linha ele deseja usar ou se deseja sair
    escolha = input("Tecle 'S' para sair do programa ou informe qual linha você gostaria de usar para gerar o relatório? (2 para a segunda, 3 para a terceira, etc.): ").strip()

    # Se o usuário quiser sair, o programa é encerrado
    if escolha.upper() == 'S':
        print("Saindo do programa. Até logo!")
        break

    # Verifica se a entrada do usuário é um número válido
    try:
        linha_escolhida = int(escolha) -2
    except ValueError:
        print("Entrada inválida. Por favor, insira um número ou 'S' para sair.")
        continue

    # Garantir que a linha escolhida está dentro do intervalo de linhas disponíveis, exceto a linha 1 (índice 0)
    if linha_escolhida == 0:
        print("A linha 1 não pode ser escolhida. Por favor, escolha outra linha.")
        continue

    if linha_escolhida < 0 or linha_escolhida >= len(df):
        print(f"Linha inválida! O arquivo tem apenas {len(df)} linhas.")
        continue

    # Passo 3: Obter os valores das células A e B da linha escolhida

    Frame =  df.iloc[linha_escolhida, idx_Frame] if pd.notna(df.iloc[linha_escolhida, idx_Frame]) else None
    Station = round(df.iloc[linha_escolhida, idx_Station], 3) if pd.notna(df.iloc[linha_escolhida, idx_Station]) else None
    OutputCase = df.iloc[linha_escolhida, idx_OutputCase] if pd.notna(df.iloc[linha_escolhida, idx_OutputCase]) else None
    CaseType = df.iloc[linha_escolhida, idx_CaseType] if pd.notna(df.iloc[linha_escolhida, idx_CaseType]) else None
    P = round(df.iloc[linha_escolhida, idx_P], 2) if pd.notna(df.iloc[linha_escolhida, idx_P]) else None
    V2 = round(df.iloc[linha_escolhida, idx_V2], 2) if pd.notna(df.iloc[linha_escolhida, idx_V2]) else None
    V3 = round(df.iloc[linha_escolhida, idx_V3], 2) if pd.notna(df.iloc[linha_escolhida, idx_V3]) else None
    T = round(df.iloc[linha_escolhida, idx_T], 2) if pd.notna(df.iloc[linha_escolhida, idx_T]) else None
    M2 = round(df.iloc[linha_escolhida, idx_M2], 2) if pd.notna(df.iloc[linha_escolhida, idx_M2]) else None
    M3 = round(df.iloc[linha_escolhida, idx_M3], 2) if pd.notna(df.iloc[linha_escolhida, idx_M3]) else None
    SectionType = df.iloc[linha_escolhida, idx_SectionType]   if pd.notna(df.iloc[linha_escolhida, idx_SectionType]) else None
    SectionName = df.iloc[linha_escolhida, idx_SectionName]   if pd.notna(df.iloc[linha_escolhida, idx_SectionName]) else None
    Material =  df.iloc[linha_escolhida, idx_Material]   if pd.notna(df.iloc[linha_escolhida, idx_Material]) else None
    Shape =  df.iloc[linha_escolhida, idx_Shape]   if pd.notna(df.iloc[linha_escolhida, idx_Shape]) else None
    t3 = round(df.iloc[linha_escolhida, idx_t3], 4) if pd.notna(df.iloc[linha_escolhida, idx_t3]) else None
    t3_mm = round(df.iloc[linha_escolhida, idx_t3]*1000, 1) if pd.notna(df.iloc[linha_escolhida, idx_t3]) else None
    t2 = round(df.iloc[linha_escolhida, idx_t2], 4) if pd.notna(df.iloc[linha_escolhida, idx_t2]) else None
    t2_mm = round(df.iloc[linha_escolhida, idx_t2]*1000, 1) if pd.notna(df.iloc[linha_escolhida, idx_t2]) else None
    tf = round(df.iloc[linha_escolhida, idx_tf], 4) if pd.notna(df.iloc[linha_escolhida, idx_tf]) else None
    tf_mm = round(df.iloc[linha_escolhida, idx_tf]*1000, 1) if pd.notna(df.iloc[linha_escolhida, idx_tf]) else None
    tw = round(df.iloc[linha_escolhida, idx_tw], 4)   if pd.notna(df.iloc[linha_escolhida, idx_tw]) else None
    tw_mm = round(df.iloc[linha_escolhida, idx_tw]*1000, 1)   if pd.notna(df.iloc[linha_escolhida, idx_tw]) else None
    t2b = round(df.iloc[linha_escolhida, idx_t2b], 4) if pd.notna(df.iloc[linha_escolhida, idx_t2b]) else None
    t2b_mm = round(df.iloc[linha_escolhida, idx_t2b]*1000, 1) if pd.notna(df.iloc[linha_escolhida, idx_t2b]) else None
    tfb = round(df.iloc[linha_escolhida, idx_tfb], 4) if pd.notna(df.iloc[linha_escolhida, idx_tfb]) else None
    tfb_mm = round(df.iloc[linha_escolhida, idx_tfb]*1000, 1) if pd.notna(df.iloc[linha_escolhida, idx_tfb]) else None
    FilletRadius = round(df.iloc[linha_escolhida, idx_FilletRadius]*1000, 0) if pd.notna(df.iloc[linha_escolhida, idx_FilletRadius]) else None
    Area = round(df.iloc[linha_escolhida, idx_Area], 4)  if pd.notna(df.iloc[linha_escolhida, idx_Area]) else None
    Area_cm = round(df.iloc[linha_escolhida, idx_Area]*10000, 4)  if pd.notna(df.iloc[linha_escolhida, idx_Area]) else None
    TorsConst = round(df.iloc[linha_escolhida, idx_TorsConst], 4)  if pd.notna(df.iloc[linha_escolhida, idx_TorsConst]) else None
    TorsConst_cm = round(df.iloc[linha_escolhida, idx_TorsConst]*100000000, 1)  if pd.notna(df.iloc[linha_escolhida, idx_TorsConst]) else None
    I33 = round(df.iloc[linha_escolhida, idx_I33], 4)  if pd.notna(df.iloc[linha_escolhida, idx_I33]) else None
    I33_cm = round(df.iloc[linha_escolhida, idx_I33]*100000000, 4)  if pd.notna(df.iloc[linha_escolhida, idx_I33]) else None
    I22 = round(df.iloc[linha_escolhida, idx_I22], 4) if pd.notna(df.iloc[linha_escolhida, idx_I22]) else None
    I22_cm = round(df.iloc[linha_escolhida, idx_I22]*100000000, 4) if pd.notna(df.iloc[linha_escolhida, idx_I22]) else None
    I23 = round(df.iloc[linha_escolhida, idx_I23]*100000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_I23]) else None
    AS2 = round(df.iloc[linha_escolhida, idx_AS2], 1) if pd.notna(df.iloc[linha_escolhida, idx_AS2]) else None
    AS2_cm = round(df.iloc[linha_escolhida, idx_AS2]*10000, 1) if pd.notna(df.iloc[linha_escolhida, idx_AS2]) else None
    AS3 = round(df.iloc[linha_escolhida, idx_AS3], 1) if pd.notna(df.iloc[linha_escolhida, idx_AS3]) else None
    AS3_cm = round(df.iloc[linha_escolhida, idx_AS3]*10000, 1) if pd.notna(df.iloc[linha_escolhida, idx_AS3]) else None
    S33 = round(df.iloc[linha_escolhida, idx_S33], 1) if pd.notna(df.iloc[linha_escolhida, idx_S33]) else None
    S33_cm = round(df.iloc[linha_escolhida, idx_S33]*1000000, 4) if pd.notna(df.iloc[linha_escolhida, idx_S33]) else None
    S22 = round(df.iloc[linha_escolhida, idx_S22], 1) if pd.notna(df.iloc[linha_escolhida, idx_S22]) else None
    S22_cm = round(df.iloc[linha_escolhida, idx_S22]*1000000, 4) if pd.notna(df.iloc[linha_escolhida, idx_S22]) else None
    Z33 = round(df.iloc[linha_escolhida, idx_Z33], 4) if pd.notna(df.iloc[linha_escolhida, idx_Z33]) else None
    Z33_cm = round(df.iloc[linha_escolhida, idx_Z33]*1000000, 4) if pd.notna(df.iloc[linha_escolhida, idx_Z33]) else None
    Z22 = round(df.iloc[linha_escolhida, idx_Z22], 4) if pd.notna(df.iloc[linha_escolhida, idx_Z22]) else None
    Z22_cm = round(df.iloc[linha_escolhida, idx_Z22]*1000000, 4) if pd.notna(df.iloc[linha_escolhida, idx_Z22]) else None
    R33 = round(df.iloc[linha_escolhida, idx_R33], 4) if pd.notna(df.iloc[linha_escolhida, idx_R33]) else None
    R33_mm = round(df.iloc[linha_escolhida, idx_R33]*1000, 4) if pd.notna(df.iloc[linha_escolhida, idx_R33]) else None
    R22 = round(df.iloc[linha_escolhida, idx_R22], 4) if pd.notna(df.iloc[linha_escolhida, idx_R22]) else None
    R22_mm = round(df.iloc[linha_escolhida, idx_R22]*1000, 4) if pd.notna(df.iloc[linha_escolhida, idx_R22]) else None
    TotalWt = round(df.iloc[linha_escolhida, idx_TotalWt], 3) if pd.notna(df.iloc[linha_escolhida, idx_TotalWt]) else None
    TotalMass = round(df.iloc[linha_escolhida, idx_TotalMass], 3) if pd.notna(df.iloc[linha_escolhida, idx_TotalMass]) else None
    Notes = df.iloc[linha_escolhida, idx_Notes] if pd.notna(df.iloc[linha_escolhida, idx_Notes]) else None
    E1 = round(df.iloc[linha_escolhida, idx_E1]/1000000, 4)  if pd.notna(df.iloc[linha_escolhida, idx_E1]) else None
    G12 = round(df.iloc[linha_escolhida, idx_G12]/1000000, 4)    if pd.notna(df.iloc[linha_escolhida, idx_G12]) else None
    U12 = round(df.iloc[linha_escolhida, idx_U12], 2) if pd.notna(df.iloc[linha_escolhida, idx_U12]) else None
    A1 = round(df.iloc[linha_escolhida, idx_A1], 2) if pd.notna(df.iloc[linha_escolhida, idx_A1]) else None
    Fy_x = round(df.iloc[linha_escolhida, idx_Fy_x]/1000, 4) if pd.notna(df.iloc[linha_escolhida, idx_Fy_x]) else None
    Fu = round(df.iloc[linha_escolhida, idx_Fu], 1) if pd.notna(df.iloc[linha_escolhida, idx_Fu]) else None
    DesignSect = df.iloc[linha_escolhida, idx_DesignSect]   if pd.notna(df.iloc[linha_escolhida, idx_DesignSect]) else None
    Combo = df.iloc[linha_escolhida, idx_Combo]   if pd.notna(df.iloc[linha_escolhida, idx_Combo]) else None
    XLMajor = round(df.iloc[linha_escolhida, idx_XLMajor], 2)   if pd.notna(df.iloc[linha_escolhida, idx_XLMajor]) else None
    XLMinor = round(df.iloc[linha_escolhida, idx_XLMinor], 2)  if pd.notna(df.iloc[linha_escolhida, idx_XLMinor]) else None
    Length = round(df.iloc[linha_escolhida, idx_Length], 3)   if pd.notna(df.iloc[linha_escolhida, idx_Length]) else None
    gamma_a1 = round(df.iloc[linha_escolhida, idx_gamma_a1], 1)  if pd.notna(df.iloc[linha_escolhida, idx_gamma_a1]) else None
    gamma_a2 = round(df.iloc[linha_escolhida, idx_gamma_a2], 1)  if pd.notna(df.iloc[linha_escolhida, idx_gamma_a2]) else None
    r_0 = round(df.iloc[linha_escolhida, idx_r_0]*1000, 1)  if pd.notna(df.iloc[linha_escolhida, idx_r_0]) else None
    C_w = round(df.iloc[linha_escolhida, idx_C_w]*10000000, 5) if pd.notna(df.iloc[linha_escolhida, idx_C_w]) else None
    C_w_mm= round(df.iloc[linha_escolhida, idx_C_w]*1000000000000000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_C_w]) else None
    N_ex = round(df.iloc[linha_escolhida, idx_N_ex], 1) if pd.notna(df.iloc[linha_escolhida, idx_N_ex]) else None
    N_ey = round(df.iloc[linha_escolhida, idx_N_ey], 1)  if pd.notna(df.iloc[linha_escolhida, idx_N_ey]) else None
    XL_z = round(df.iloc[linha_escolhida, idx_XL_z], 2) if pd.notna(df.iloc[linha_escolhida, idx_XL_z]) else None
    N_ez = round(df.iloc[linha_escolhida, idx_N_ez], 1) if pd.notna(df.iloc[linha_escolhida, idx_N_ez]) else None
    N_ec = round(df.iloc[linha_escolhida, idx_N_ec] , 1) if pd.notna(df.iloc[linha_escolhida, idx_N_ec]) else None
    N_et_1 = round(df.iloc[linha_escolhida, idx_N_et_1], 1) if pd.notna(df.iloc[linha_escolhida, idx_N_et_1]) else None
    N_et_2 = round(df.iloc[linha_escolhida, idx_N_et_2], 1) if pd.notna(df.iloc[linha_escolhida, idx_N_et_2]) else None
    N_t_Rd = round(df.iloc[linha_escolhida, idx_N_t_Rd], 1)  if pd.notna(df.iloc[linha_escolhida, idx_N_t_Rd]) else None
    bt_lim_inf_grupo_02 = round(df.iloc[linha_escolhida, idx_bt_lim_inf_grupo_02], 1) if pd.notna(df.iloc[linha_escolhida, idx_bt_lim_inf_grupo_02]) else None
    bt_lim_inf_grupo_04 = round(df.iloc[linha_escolhida, idx_bt_lim_inf_grupo_04], 1) if pd.notna(df.iloc[linha_escolhida, idx_bt_lim_inf_grupo_04]) else None
    lambda_0 = round(df.iloc[linha_escolhida, idx_lambda_0], 3)  if pd.notna(df.iloc[linha_escolhida, idx_lambda_0]) else None
    chi = round(df.iloc[linha_escolhida, idx_chi], 4)  if pd.notna(df.iloc[linha_escolhida, idx_chi]) else None
    sigma_el_alma = round(df.iloc[linha_escolhida, idx_sigma_el_alma], 1) if pd.notna(df.iloc[linha_escolhida, idx_sigma_el_alma]) else None
    sigma_el_mesa_sup =  round(df.iloc[linha_escolhida, idx_sigma_el_mesa_sup], 1) if pd.notna(df.iloc[linha_escolhida, idx_sigma_el_mesa_sup]) else None
    sigma_el_mesa_inf =  round(df.iloc[linha_escolhida, idx_sigma_el_mesa_inf], 1) if pd.notna(df.iloc[linha_escolhida, idx_sigma_el_mesa_inf]) else None
    teste_sigma_el_alma = df.iloc[linha_escolhida, idx_teste_sigma_el_alma]   if pd.notna(df.iloc[linha_escolhida, idx_teste_sigma_el_alma]) else None
    teste_sigma_el_mesa_sup = df.iloc[linha_escolhida, idx_teste_sigma_el_mesa_sup]   if pd.notna(df.iloc[linha_escolhida, idx_teste_sigma_el_mesa_sup]) else None
    teste_sigma_el_mesa_inf = df.iloc[linha_escolhida, idx_teste_sigma_el_mesa_inf]   if pd.notna(df.iloc[linha_escolhida, idx_teste_sigma_el_mesa_inf]) else None
    compacto =  df.iloc[linha_escolhida, idx_compacto]   if pd.notna(df.iloc[linha_escolhida, idx_compacto]) else None
    b_ef_alma =  round(df.iloc[linha_escolhida, idx_b_ef_alma], 4) if pd.notna(df.iloc[linha_escolhida, idx_b_ef_alma]) else None
    b_ef_mesa_sup =  round(df.iloc[linha_escolhida, idx_b_ef_mesa_sup], 4)  if pd.notna(df.iloc[linha_escolhida, idx_b_ef_mesa_sup]) else None
    b_ef_mesa_inf =  round(df.iloc[linha_escolhida, idx_b_ef_mesa_inf], 4) if pd.notna(df.iloc[linha_escolhida, idx_b_ef_mesa_inf]) else None
    Area_ef =  round(df.iloc[linha_escolhida, idx_Area_ef]* 10000, 1) if pd.notna(df.iloc[linha_escolhida, idx_Area_ef]) else None
    N_c_Rd =  round(df.iloc[linha_escolhida, idx_N_c_Rd], 1) if pd.notna(df.iloc[linha_escolhida, idx_N_c_Rd]) else None
    N_Rd =  round(df.iloc[linha_escolhida, idx_N_Rd], 1) if pd.notna(df.iloc[linha_escolhida, idx_N_Rd]) else None
    C_b =  round(df.iloc[linha_escolhida, idx_C_b], 2)  if pd.notna(df.iloc[linha_escolhida, idx_C_b]) else None
    y_c =  round(df.iloc[linha_escolhida, idx_y_c]*100, 1) if pd.notna(df.iloc[linha_escolhida, idx_y_c]) else None
    beta_1 =  round(df.iloc[linha_escolhida, idx_beta_1], 3)   if pd.notna(df.iloc[linha_escolhida, idx_beta_1]) else None
    I_x_sup =  round(df.iloc[linha_escolhida, idx_I_x_sup]*100000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_I_x_sup]) else None
    I_x_inf =  round(df.iloc[linha_escolhida, idx_I_x_inf]*100000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_I_x_inf]) else None
    Area_x_sup =  round(df.iloc[linha_escolhida, idx_Area_x_sup]*10000, 1) if pd.notna(df.iloc[linha_escolhida, idx_Area_x_sup]) else None
    Area_x_inf =  round(df.iloc[linha_escolhida, idx_Area_x_inf]*10000, 1) if pd.notna(df.iloc[linha_escolhida, idx_Area_x_inf]) else None
    r_x_sup =  round(df.iloc[linha_escolhida, idx_r_x_sup]*100, 2)   if pd.notna(df.iloc[linha_escolhida, idx_r_x_sup]) else None
    r_x_inf =  round(df.iloc[linha_escolhida, idx_r_x_inf]*100, 2)  if pd.notna(df.iloc[linha_escolhida, idx_r_x_inf]) else None
    W_x_sup =  round(df.iloc[linha_escolhida, idx_W_x_sup]*1000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_W_x_sup]) else None
    W_x_inf =  round(df.iloc[linha_escolhida, idx_W_x_inf]*1000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_W_x_inf]) else None
    W_x_c =  round(df.iloc[linha_escolhida, idx_W_x_c]*1000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_W_x_c]) else None
    W_x_t =  round(df.iloc[linha_escolhida, idx_W_x_t], 1)  if pd.notna(df.iloc[linha_escolhida, idx_W_x_t]) else None
    I_y_esq =  round(df.iloc[linha_escolhida, idx_I_y_esq]* 100000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_I_y_esq]) else None
    I_y_dir =  round(df.iloc[linha_escolhida, idx_I_y_dir]*100000000, 1)  if pd.notna(df.iloc[linha_escolhida, idx_I_y_dir]) else None
    Area_y_esq =  round(df.iloc[linha_escolhida, idx_Area_y_esq]*10000, 1) if pd.notna(df.iloc[linha_escolhida, idx_Area_y_esq]) else None
    Area_y_dir =  round(df.iloc[linha_escolhida, idx_Area_y_dir]*10000, 1)  if pd.notna(df.iloc[linha_escolhida, idx_Area_y_dir]) else None
    r_y_esq =  round(df.iloc[linha_escolhida, idx_r_y_esq]*100, 1) if pd.notna(df.iloc[linha_escolhida, idx_r_y_esq]) else None
    r_y_dir =  round(df.iloc[linha_escolhida, idx_r_y_dir]*100, 1) if pd.notna(df.iloc[linha_escolhida, idx_r_y_dir]) else None
    W_y_esq =  round(df.iloc[linha_escolhida, idx_W_y_esq]*1000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_W_y_esq]) else None
    W_y_dir =  round(df.iloc[linha_escolhida, idx_W_y_dir]*1000000, 1) if pd.notna(df.iloc[linha_escolhida, idx_W_y_dir]) else None
    W_y_c =  round(df.iloc[linha_escolhida, idx_W_y_c], 1) if pd.notna(df.iloc[linha_escolhida, idx_W_y_c]) else None
    W_y_t =  round(df.iloc[linha_escolhida, idx_W_y_t], 1) if pd.notna(df.iloc[linha_escolhida, idx_W_y_t]) else None
    M_r_tipo_1_FLT =  round(df.iloc[linha_escolhida, idx_M_r_tipo_1_FLT], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_r_tipo_1_FLT]) else None
    M_cr_tipo_1_FLT =  round(df.iloc[linha_escolhida, idx_M_cr_tipo_1_FLT], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_cr_tipo_1_FLT]) else None
    lambda_tipo_1_FLT =  round(df.iloc[linha_escolhida, idx_lambda_tipo_1_FLT], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_tipo_1_FLT]) else None
    lambda_p_tipo_1_FLT =  round(df.iloc[linha_escolhida, idx_lambda_p_tipo_1_FLT], 2)   if pd.notna(df.iloc[linha_escolhida, idx_lambda_p_tipo_1_FLT]) else None
    lambda_r_tipo_1_FLT =  round(df.iloc[linha_escolhida, idx_lambda_r_tipo_1_FLT], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_r_tipo_1_FLT]) else None
    M_pl_tipo_1_FLT =  round(df.iloc[linha_escolhida, idx_M_pl_tipo_1_FLT], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_pl_tipo_1_FLT]) else None
    M_r_tipo_1_FLM =  round(df.iloc[linha_escolhida, idx_M_r_tipo_1_FLM], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_r_tipo_1_FLM]) else None
    M_cr_tipo_1_FLM =  round(df.iloc[linha_escolhida, idx_M_cr_tipo_1_FLM], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_cr_tipo_1_FLM]) else None
    lambda_tipo_1_FLM =  round(df.iloc[linha_escolhida, idx_lambda_tipo_1_FLM], 2)  if pd.notna(df.iloc[linha_escolhida, idx_lambda_tipo_1_FLM]) else None
    lambda_p_tipo_1_FLM =  round(df.iloc[linha_escolhida, idx_lambda_p_tipo_1_FLM], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_p_tipo_1_FLM]) else None
    lambda_r_tipo_1_FLM =  round(df.iloc[linha_escolhida, idx_lambda_r_tipo_1_FLM], 2)  if pd.notna(df.iloc[linha_escolhida, idx_lambda_r_tipo_1_FLM]) else None
    M_pl_tipo_1_FLM =  round(df.iloc[linha_escolhida, idx_M_pl_tipo_1_FLM], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_pl_tipo_1_FLM]) else None
    M_r_tipo_1_FLA =  round(df.iloc[linha_escolhida, idx_M_r_tipo_1_FLA], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_r_tipo_1_FLA]) else None
    M_cr_tipo_1_FLA =  df.iloc[linha_escolhida, idx_M_cr_tipo_1_FLA] if pd.notna(df.iloc[linha_escolhida, idx_M_cr_tipo_1_FLA]) else None
    lambda_tipo_1_FLA =  round(df.iloc[linha_escolhida, idx_lambda_tipo_1_FLA], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_tipo_1_FLA]) else None
    lambda_p_tipo_1_FLA =  round(df.iloc[linha_escolhida, idx_lambda_p_tipo_1_FLA], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_p_tipo_1_FLA]) else None
    lambda_r_tipo_1_FLA =  round(df.iloc[linha_escolhida, idx_lambda_r_tipo_1_FLA], 2)   if pd.notna(df.iloc[linha_escolhida, idx_lambda_r_tipo_1_FLA]) else None
    M_pl_tipo_1_FLA =  round(df.iloc[linha_escolhida, idx_M_pl_tipo_1_FLA], 1)   if pd.notna(df.iloc[linha_escolhida, idx_M_pl_tipo_1_FLA]) else None
    M_r_tipo_3_FLM =  round(df.iloc[linha_escolhida, idx_M_r_tipo_3_FLM], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_r_tipo_3_FLM]) else None
    M_cr_tipo_3_FLM =  round(df.iloc[linha_escolhida, idx_M_cr_tipo_3_FLM], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_cr_tipo_3_FLM]) else None
    lambda_tipo_3_FLM =  round(df.iloc[linha_escolhida, idx_lambda_tipo_3_FLM], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_tipo_3_FLM]) else None
    lambda_p_tipo_3_FLM =  round(df.iloc[linha_escolhida, idx_lambda_p_tipo_3_FLM], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_p_tipo_3_FLM]) else None
    lambda_r_tipo_3_FLM =  round(df.iloc[linha_escolhida, idx_lambda_r_tipo_3_FLM], 2)  if pd.notna(df.iloc[linha_escolhida, idx_lambda_r_tipo_3_FLM]) else None
    M_pl_tipo_3_FLM =  round(df.iloc[linha_escolhida, idx_M_pl_tipo_3_FLM], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_pl_tipo_3_FLM]) else None
    M_Rd_tipo_1_FLT =  round(df.iloc[linha_escolhida, idx_M_Rd_tipo_1_FLT], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_Rd_tipo_1_FLT]) else None
    M_Rd_tipo_1_FLM =  round(df.iloc[linha_escolhida, idx_M_Rd_tipo_1_FLM], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_Rd_tipo_1_FLM]) else None
    M_Rd_tipo_1_FLA =  round(df.iloc[linha_escolhida, idx_M_Rd_tipo_1_FLA], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_Rd_tipo_1_FLA]) else None
    M_Rd_tipo_1 =  round(df.iloc[linha_escolhida, idx_M_Rd_tipo_1], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_Rd_tipo_1]) else None
    M_Rd_tipo_3_FLM =  round(df.iloc[linha_escolhida, idx_M_Rd_tipo_3_FLM], 1)  if pd.notna(df.iloc[linha_escolhida, idx_M_Rd_tipo_3_FLM]) else None
    M_Rd_tipo_3 =  round(df.iloc[linha_escolhida, idx_M_Rd_tipo_3], 1) if pd.notna(df.iloc[linha_escolhida, idx_M_Rd_tipo_3]) else None
    V_pl_vert =  round(df.iloc[linha_escolhida, idx_V_pl_vert], 1)  if pd.notna(df.iloc[linha_escolhida, idx_V_pl_vert]) else None
    k_v_vert =  round(df.iloc[linha_escolhida, idx_k_v_vert], 2) if pd.notna(df.iloc[linha_escolhida, idx_k_v_vert]) else None
    lambda_V_Rd_vert =  round(df.iloc[linha_escolhida, idx_lambda_V_Rd_vert], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_V_Rd_vert]) else None
    lambda_p_V_Rd_vert =  round(df.iloc[linha_escolhida, idx_lambda_p_V_Rd_vert], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_p_V_Rd_vert]) else None
    lambda_r_V_Rd_vert =  round(df.iloc[linha_escolhida, idx_lambda_r_V_Rd_vert], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_r_V_Rd_vert]) else None
    V_Rd_vert =  round(df.iloc[linha_escolhida, idx_V_Rd_vert], 1) if pd.notna(df.iloc[linha_escolhida, idx_V_Rd_vert]) else None
    V_Sd_V_Rd_vert =  round(df.iloc[linha_escolhida, idx_V_Sd_V_Rd_vert], 7)  if pd.notna(df.iloc[linha_escolhida, idx_V_Sd_V_Rd_vert]) else None
    V_pl_horz =  round(df.iloc[linha_escolhida, idx_V_pl_horz], 1)  if pd.notna(df.iloc[linha_escolhida, idx_V_pl_horz]) else None
    k_v_horz =  round(df.iloc[linha_escolhida, idx_k_v_horz], 2)  if pd.notna(df.iloc[linha_escolhida, idx_k_v_horz]) else None
    lambda_V_Rd_horz =  round(df.iloc[linha_escolhida, idx_lambda_V_Rd_horz], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_V_Rd_horz]) else None
    lambda_p_V_Rd_horz =  round(df.iloc[linha_escolhida, idx_lambda_p_V_Rd_horz], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_p_V_Rd_horz]) else None
    lambda_r_V_Rd_horz =  round(df.iloc[linha_escolhida, idx_lambda_r_V_Rd_horz], 2) if pd.notna(df.iloc[linha_escolhida, idx_lambda_r_V_Rd_horz]) else None
    V_Rd_horz =  round(df.iloc[linha_escolhida, idx_V_Rd_horz], 1) if pd.notna(df.iloc[linha_escolhida, idx_V_Rd_horz]) else None
    V_Sd_V_Rd_horz =  round(df.iloc[linha_escolhida, idx_V_Sd_V_Rd_horz], 7) if pd.notna(df.iloc[linha_escolhida, idx_V_Sd_V_Rd_horz]) else None
    N_Sd_N_Rd =  round(df.iloc[linha_escolhida, idx_N_Sd_N_Rd], 3) if pd.notna(df.iloc[linha_escolhida, idx_N_Sd_N_Rd]) else None
    M_xSd_M_xRd =  round(df.iloc[linha_escolhida, idx_M_xSd_M_xRd], 3) if pd.notna(df.iloc[linha_escolhida, idx_M_xSd_M_xRd]) else None
    M_ySd_M_yRd =  round(df.iloc[linha_escolhida, idx_M_ySd_M_yRd], 3) if pd.notna(df.iloc[linha_escolhida, idx_M_ySd_M_yRd]) else None
    item_nota = df.iloc[linha_escolhida, idx_item_nota]  if pd.notna(df.iloc[linha_escolhida, idx_item_nota]) else None
    Verificação_PMM =  round(df.iloc[linha_escolhida, idx_Verificação_PMM], 3) if pd.notna(df.iloc[linha_escolhida, idx_Verificação_PMM]) else None


    # Passo 4: Criar o conteúdo em LaTeX
    latex_content_trecho_A= rf"""
    
\documentclass[11pt]<article>
\usepackage<amsfonts,amssymb,amsmath>
\usepackage<float>
\usepackage[portuguese]<babel>
\usepackage<geometry>
\usepackage<titlesec>
\usepackage<enumitem>

\geometry<
    paperwidth=210mm,        % Largura da página (A4)
    paperheight=297mm,       % Altura da página (A4)
    left=2cm,                % Margem esquerda
    right=2cm,               % Margem direita
    top=.1cm,                 % Margem superior
    bottom=1cm,              % Margem inferior
    heightrounded,           % Ajusta a altura da página para ser um número inteiro de linhas
    includehead,             % Inclui o cabeçalho no cálculo da altura total da página
    includefoot              % Inclui o rodapé no cálculo da altura total da página
>

\setcounter<secnumdepth><5>

\titleformat<\paragraph>
<\normalfont\normalsize\bfseries><\theparagraph><1em><>
\titlespacing*<\paragraph><0pt><3.25ex plus 1ex minus .2ex><1.5ex plus .2ex>

\titleformat<\subparagraph>
<\normalfont\normalsize\bfseries><\thesubparagraph><1em><>
\titlespacing*<\subparagraph><0pt><3.25ex plus 1ex minus .2ex><1.5ex plus .2ex>




\begin<document>

\tableofcontents % Gera o índice automaticamente

\section<Introdução>
Esta memória de cálculo tem como objetivo demonstrar a verificação completa do perfil metálico chamado \textit<{Frame}>, a qual foi 
adotada a seção \textit<{SectionName}>, localizado a ${Station}m$ a partir do ponto inicial da barra, seguindo as premissas estabelecidas na norma NBR8800:2024 
(Projeto de estruturas de aço e de estruturas mistas de aço e concreto de edificações).
\\

"""

    latex_content_trecho_B= rf"""

\section<Documentos de Referência>
Os documentos de referência utilizados para elaboração desta memória são:\\
NBR8800:2024 - Projeto de estruturas de aço e de estruturas mistas de aço e concreto de edificações;\\
NBR6120:2019 - Ações para o cálculo de estruturas de edificações;\\
NBR6123:2023 - Forças devidas ao vento em edificações.\\


"""

    latex_content_trecho_C= rf"""


\section<Propriedades dos Perfil>
\subsection<Propriedades Geométricas>
As dimensões do perfil são apresentadas nesta seção a seguir:
\begin<table>[H]
\def\arraystretch<2>
\caption<Dimensões do perfil - propriedades geométricas da seção>
\begin<center>
\begin<tabular><|c||c|c|c|c|c|c|>
    \hline
        $Barra$   &   $Perfil$    &  $h (mm)$   &  $b_f (mm)$   &   $t_f (mm)$   &  $t_w (mm)$   &   $A (cm^2)$  \\ \hline            
        {Frame}   & {SectionName} &   {t3_mm}   &   {t2_mm}     &    {tf_mm}     &    {tw_mm}    &    {Area_cm}  \\ \hline 
\end<tabular>
\end<center>
\end<table>

Sendo:\\
$h$ é a altura do perfil;\\
$b_f$ é a largura do perfil;\\
$t_f$ é a espessura da mesa;\\
$t_w$ é a espessura da alma;\\
$A$ é a área do perfil.
\\

"""

    latex_content_trecho_D= rf"""

\subsection<Propriedades Mecânicas>
As caracterísitcas geométricas do perfil estão disponíveis na tabelas a seguir:

\begin<table>[H]
\def\arraystretch<1.3>
\caption<Dimensões do perfil - propriedades geométricas da seção (parte 1/2)>
\begin<center>
\begin<tabular><|c||c|c|c|c|c|c|>
\hline
Barra   &   Perfil      &  $J (cm^4)$       &  $I_x (cm^4)$  &  $I_y (cm^4)$ & $A_<w,y> (cm^2)$  & $A_<w,x> (cm^2)$     \\ \hline            
{Frame} & {SectionName} &   {TorsConst_cm}  &     {I33_cm}   &   {I22_cm}    &   {AS2_cm}        &   {AS3_cm}           \\ \hline 
\end<tabular>
\end<center>
\end<table>

\begin<table>[H]
\def\arraystretch<1.3>
\caption<Dimensões do perfil - propriedades geométricas da seção (parte 2/2)>
\begin<center>
\begin<tabular><|c||c|c|c|c|c|c|c|>
\hline
Barra   &    Perfil     &    $W_x (cm^3)$    &  $W_y (cm^3)$    &   $Z_x (cm^3)$    &    $Z_y (cm^3)$   &   $r_x (mm)$   &   $r_y (mm)$    \\ \hline            
{Frame} & {SectionName} &      {S33_cm}      &     {S22_cm}     &     {Z33_cm}      &      {Z22_cm}     &    {R22_mm}    &     {R33_mm}    \\ \hline 
\end<tabular>
\end<center>
\end<table>

Sendo:\\
$J$ é a constante de torção;\\
$I_x$ é o momento de inércia no eixo de maior inércia;\\
$I_y$ é o momento de inércia no eixo de menor Inércia;\\
$A_<w,y>$ é a área efetiva de cisalhamento na direção vertical;\\
$A_<w,x>$ é a área efetiva de cisalhamento na direção horizontal;\\
$W_x$ é o módulo de resistência elástico no eixo de maior inércia;\\
$W_y$ é o módulo de resistência elástico no eixo de menor inércia;\\
$Z_x$ é o módulo de resistência plástico no eixo de maior inércia;\\
$Z_y$ é o módulo de resistência plástico no eixo de menor inércia;\\
$r_x$ é o raio de giração em torno do eixo de maior inércia;\\
$r_y$ é o raio de giração em torno do eixo de menor inércia.\\



O raio de giração polar da seção bruta em relação ao centro de cisalhamento, calculado conforme a seguinte equação: 

$$r_0 =\sqrt<<<r_x>^2 + <r_y>^2>> = \sqrt<<{R22}^2> + <{R33}^2>> = {r_0}mm$$
\\

Constante de empenamento da seção transversal, calculado conforme item D.2.8.a) da NBR8800:2024

$$C_w = \frac<I_y(d-t_f)^2><4> = \frac<{I22_cm}*10^<-8> * ({t3}-{tf})^2><4> = {C_w}*10^<-7>m^6$$
\\

"""

    latex_content_trecho_E= rf"""

\section<Esforços Solicitantes do Perfil>
Para determinação dos esforços internos nas barras da estrutura, foi utilizado o software SAP2000 v.23.3.1, 
para modelagem, lançamento de carregamento e análise da estrutura. O software SAP2000 é um programa de análise
estrutural desenvolvido pela Computers and Structures, Inc. (CSI), que é amplamente utilizado para modelagem, 
análise e dimensionamento de estruturas com foco em engenharia civil (concreto e metálica). 

Para esta análise foi escolhido o ponto localizado a ${Station}m$ do ponto inicial da barra \textit<{Frame}>. Ao avaliar
todas as combinações de esforços que esta barra esta submetida, a combinação \textit<{Combo}> é a que impõe os maiores 
esforços internos sobre a seção. A seguir são apresentando os esforços internos que foram considerado na verificação do perfil:

\begin<table>[H]
    \def\arraystretch<1.3>
    \caption<Esforçco Solicitantes Internos na Barra>
    \begin<center>
    \begin<tabular><|p<1cm>||p<2.5cm>|p<1.1cm>|p<1.1cm>|p<1.1cm>|p<1.1cm>|p<1.1cm>|p<1.1cm>|>
        \hline
            Barra   & Combinação      & P  $(kN)$   &   V2 $(kN)$  &   V3 $(kN)$  &    T $(kN.m)$ &	   M2 $(kN.m)$   &     M3 $(kN.m)$   \\ \hline            
            {Frame} & {OutputCase}    &      {P}    &      {V2}    &      {V3}    &       {T}     &       {M2}       &       {M3}        \\ \hline 
    \end<tabular>
    \end<center>
    \end<table>

Sendo: \\
$P$ é a Força Axial na mesma direção do eixo do perfil;\\
$V2$ é a Força Cortante na mesma direção da alma do perfil;\\
$V3$ é a Força Cortante na mesma direção das mesas do perfil;\\
$T$ é o Momentor Torsor na mesma direção do eixo do perfil;\\
$M2$ é o Momento Fletor que atua no eixo de maior inércia;\\ 
$M3$ é o Momento Flexor que atua no eixo de menor inércia.\\


"""

    latex_content_trecho_F= rf"""

\section<Esforços Resistentes do Perfil>
Tendo em vista que o esforço axial solicitante do perfil, no ponto escolhido para análise, é um esforço de compressão ou tração, 
então a verificação adotada é aquela descrita no item 5.3 da Norma NBR8800:2024. 

"""

    latex_content_trecho_G= np.where(P < 0 , rf"""

\subsection<Força Axial de Compressão Resistente>
Para barra comprimidas, deve ser atendida a condição:

$$N_<c,Sd> \leq N_<c,Rd>$$

Onde:\\
$N_<c,Sd>$ é a força axial de compressão solicitante de cálculo;\\
$N_<c,Rd>$ é a força axial de compressão resistente de cálculo, determinada conforme 5.3.2.\\

Para se determinar o $N_<c,Rd>$, antes é necessário saber qual é o valor da força axial de flambagem ($N_e$), que será visto no próximo item desta memória.\\

""",
"""   """).item()

    latex_content_trecho_H= np.where(P < 0 , rf"""

\subsubsection<Força Axial de Flambagem>
A força axial de flambagem de uma barra com seção transversal duplamente simétrica ou simétrica em relação a um ponto é o menor dos três valores dados a seguir:\\

a) para flambagem por flexão em relação ao eixo central de inércia x da seção transversal:

$$N_<ex> = \frac<<\pi ^2>.E.I_x><<L_x>^2> = \frac<3.1415^2 * ({E1}*10^9) * ({I33_cm}*10^<-8>) ><(<{XLMajor}*{Length}>)^2> = {N_ex} kN$$
\\

b) para flambagem por flexão em relação ao eixo central de inércia y da seção transversal:

$$N_<ey> = \frac<<\pi ^2>.E.I_y><<L_y>^2> = \frac<3.1415^2 * ({E1}*10^9) * ({I22_cm}*10^<-8>) ><(<{XLMinor}*{Length}>)^2> = {N_ey} kN$$
\\


c) para flambagem por torção em relação ao eixo longitudinal z (que passa pelo centro de cisalhamento):

$$N_<ez> = \frac<1><r_0^2><\left[\frac<<\pi ^2>.E.C_w><L_z^2> + G.J \right]> = $$
$$\frac<1><({r_0}*10^<-3>)^2> <\left[\frac<<3.1415 ^2> * ({E1}*10^9) * ({C_w}*10^<-7>)><(<{XL_z}*{Length}>)^2> + ({G12}*10^6) * ({TorsConst_cm}*10^<-8>) \right]> = {N_ez} kN$$
\\

Onde:

$L_x$ é o comprimento destravado associado à flexão em relação ao eixo $x$;

$I_x$ é o momento de inércia da seção transversal em relação ao eixo $x$;

$L_y$ é o comprimento destravado associado à flexão em relação ao eixo $y$;

$I_y$ é o momento de inércia da seção transversal em relação ao eixo $y$;

$L_z$ é o comprimento destravado associado à torção;

$E$ é o módulo de elasticidade do aço;

$C_w$ é a constante de empenamento da seção transversal;

$G$ é o módulo de elasticidade transversal do aço;

$J$ é a constante de torção da seção transversal;

$r_0$ é o raio de giração polar da seção bruta em relação ao centro de cisalhamento, conforme previamente detalhado. 
\\

Como o menor valor entre $N_<ex>$, $N_<ey>$ e $N_<ez>$ é ${N_ec}$, então $N_e = {N_ec} kN$.\\

Com o valor de $N_e$ determinado, deve-se voltar para o item 5.3.2 da NBR8800:2024 para determinar o Índice de
esbeltez reduzido ($\lambda_0$), Conforme item  em 5.3.3.2.

 """,
"""   """).item()

    latex_content_trecho_I= np.where(P < 0 , rf"""

\subsubsection<Índice de Esbeltez Reduzido ($\lambda_0$) >

O índice de esbeltez reduzido ($\lambda_0$) é calculado pela seguinte equação:

$$\lambda_0 = \sqrt<\frac<A_g.f_y><N_e>> = \sqrt<\frac<{Area} * ({Fy_x}*10^6) ><{N_ec}*10^3 >> = {lambda_0}$$

Com $\lambda_0$ determinado, deve-se calcular o valor do fator de redução associado à resistência à compressão ($\chi$).\\


""",
"""   """).item()

    latex_content_trecho_J= np.where(P < 0 , rf"""
\subsubsection<Fator de Redução Associado à Resistência à Compressão ($\chi$)>

O fator de redução associado à resistência à compressão ($\chi$) é calculado pela seguinte equação:\\

\( \rightarrow  \) para $\lambda_0 \leq 1.5$ : 
$$\chi = 0.658^<<\lambda_0>^2>$$ 
\\

\( \rightarrow  \) para $\lambda_0 \textgreater 1.5$ : 
$$\chi=\frac<0.877><<\lambda_0>^2>$$
\\

""",
"""   """).item()

    latex_content_trecho_K= np.where((P < 0) & (lambda_0 <= 1.5) , rf"""

Como $<\lambda_0> \leq 1.5$, então:
$$\chi = 0.658^<<\lambda_0>^2>=0.658^<{lambda_0}^2>={chi}$$
\\

""",
"""   """).item()
    
    latex_content_trecho_L= np.where((P < 0) & (lambda_0 > 1.5) , rf"""

Como $\lambda_0 \textgreater 1.5$, então :
$$\chi=\frac<0.877><<\lambda_0>^2> = \frac<0.877><{lambda_0}^2> = {chi}$$
\\

""",
"""   """).item()

    latex_content_trecho_M= np.where(P < 0 , rf"""
Com $\chi$ determinado, o último valor a ser determinado é área efetiva da seção transversal da barra ($A_<ef>$), conforme item 5.3.4 da NBR8800:2024.\\

""",
"""   """).item()

    latex_content_trecho_N= np.where(P < 0 , rf"""

\subsubsection<Área Efetiva da Seção Transversal da Barra ($A_<ef>$)>
Os elementos que fazem parte das seções transversais usuais para efeito de flambagem local, 
são classificados em:

\( \rightarrow  \) (AA) duas bordas longitudinais apoiadas como, por exemplo, almas de seções I, H ou U; e

\( \rightarrow  \) (AL) uma borda longitudinal apoiada e outra livre como, por exemplo, mesas de seções I, H, T ou U laminadas.
\\

A área efetiva da seção transversal ($A_<ef>$) deve ser considerada igual à área bruta ($A_g$) se 
todos os elementos componentes da seção transversal (AA ou AL) possuírem razão entre largura
e espessura ($b/t$) igual ou inferior ao valor $((b/t)_<lim>/\sqrt<\chi>)$.
\\

Vale ressaltar que:

\( \rightarrow  \) para elementos do tipo AA, ($b/t$) é a razão entre distância entre mesas do perfil e espessura da alma ($(h-2.t_f)/t_w$);

\( \rightarrow  \) para elementos do tipo AL, ($b/t$) é a razão entre meia largura do perfil e espessura da mesa ($0.5b/t_f$).
\\

Como a \textbf<largura efetiva da alma> é em função da esbeltez da chapa que compõem a alma, deve-se verificar
dentro das faixas em que este valor está trabalhando. A partir disto, aplicar uma das duas expressões a seguir para 
o valor de \textbf<largura efetiva da alma>:\\
                                     
\( \rightarrow  \) para $\displaystyle \frac<(h-2.t_f)><t_w> \leq \frac<(b/t)_<lim>><\sqrt<\chi>>$: $b_<ef,alma> = (h-2.t_f)$ ou 
\\[10pt]

\( \rightarrow  \) para $\displaystyle \frac<(h-2.t_f)><t_w> \textgreater \frac<(b/t)_<lim>><\sqrt<\chi>>$: $\displaystyle  b_<ef,alma>=(h-2.t_f)\left(1-0.18<\sqrt<\frac<\sigma_<el>><\chi f_y>>>\right) \sqrt<\frac<\sigma_<el>><\chi f_y>>$; 
\\[10pt]

<sendo $\displaystyle \sigma_<el> = \left(1.31<\frac<<(b/t)_<lim>>><(h-2.t_f)/t_w>>\right)^2 f_y$>
\\[25pt]

""" ,
"""   """).item()

    latex_content_trecho_O= np.where((P < 0) & (((t3-2*tf)/(tw)) <= ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

O valor limite para esbeltez da alma é:\\

$$(b/t)_<lim> = 1.49\sqrt<\frac<E><f_y>> = 1.49\sqrt<\frac< {E1}*10^9 >< {Fy_x}*10^6 >> = {bt_lim_inf_grupo_02}$$

\vspace<0.3cm>

A relação entre esbeltez da alma e o valor limite é:\\
\\
\centerline <$\displaystyle \frac<(h-2.t_f)><t_w> \leq \frac<(b/t)_<lim>><\sqrt<\chi>>$ \( \Rightarrow  \) 
$\displaystyle \frac<({t3}-2*{tf})><{tw}> \leq \frac<{bt_lim_inf_grupo_02}><\sqrt<{chi}>>$>

\vspace<0.3cm>

Como a esbeltez da alma é menor ou igual do que o valor limite, a \textbf<largura efetiva da alma> é dada por:\\

$$b_<ef,alma> = (h-2.t_f) = ({t3} - 2*{tf}) = {b_ef_alma}m$$

\vspace<0.3cm>


""" ,
"""   """).item()

    latex_content_trecho_P= np.where((P < 0) & (((t3-2*tf)/(tw)) > ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

O valor limite para esbeltez da alma é:\\

$$(b/t)_<lim> = 1.49\sqrt<\frac<E><f_y>> = 1.49\sqrt<\frac<{E1}*10^9 ><{Fy_x}*10^6 >> = {bt_lim_inf_grupo_02} $$\\

\vspace<0.3cm>


A relação entre esbeltez da alma e o valor limite é:\\
\\
\centerline <$\displaystyle \frac<(h-2.t_f)><t_w> \textgreater \frac<(b/t)_<lim>><\sqrt<\chi>>$ \( \Rightarrow  \) 
$\displaystyle \frac<({t3}-2*{tf})><{tw}> \textgreater \frac<{bt_lim_inf_grupo_02}><\sqrt<{chi}>>$>

\vspace<0.3cm>

Como a esbeltez da alma é maior do que o valor limite, a \textbf<largura efetiva da alma> é dada por:\\

$$\sigma_<el> = \left(1.31<\frac<<(b/t)_<lim>>><(h-2.t_f)/t_w>>\right)^2 f_y = {sigma_el_alma}$$

\vspace<0.3cm>

$$b_<ef,alma>=(h-2.t_f)\left(1-0.18<\sqrt<\frac<\sigma_<el>><\chi f_y>>>\right) \sqrt<\frac<\sigma_<el>><\chi f_y>> = {b_ef_alma}m$$

\vspace<1cm>

""",
"""   """).item()

    latex_content_trecho_Q= np.where((P < 0) , rf"""

Como a \textbf<largura efetiva da mesa> é em função da esbeltez de meia chapa que compõem a mesa, deve-se verificar
dentro das faixas em que este valor está trabalhando. A partir disto, aplicar uma das duas expressões a seguir para 
o valor de \textbf<largura efetiva da mesa>:\\
                                     
\( \rightarrow  \) para $\displaystyle \frac<0.5b><t_f> \leq \frac<(b/t)_<lim>><\sqrt<\chi>>$: $b_<ef> = 0.5b$ ou
\\[10pt]
                                     
 \( \rightarrow  \) para $\displaystyle \frac<0.5b><t_f> \textgreater \frac<(b/t)_<lim>><\sqrt<\chi>>$: $\displaystyle  b_<ef>=0.5b\left(1-0.22<\sqrt<\frac<\sigma_<el>><\chi f_y>>>\right) \sqrt<\frac<\sigma_<el>><\chi f_y>>$; 
\\[10pt]

<sendo $\displaystyle \sigma_<el> = \left(1.49<\frac<<(b/t)_<lim>>><(0.5b)/t_f>>\right)^2 f_y$>
\\[25pt]

""" ,
"""   """).item()

    latex_content_trecho_R= np.where((P < 0) & (((t3-2*tf)/(tw)) <= ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

 

""",
"""   """).item()

    latex_content_trecho_S= np.where((P < 0) & (((t3-2*tf)/(tw)) > ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

 

""" ,
"""   """).item()

    latex_content_trecho_T= np.where((P < 0) & (((t3-2*tf)/(tw)) <= ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

 

""" ,
"""   """).item()
    
    latex_content_trecho_U= np.where((P < 0) & (((t3-2*tf)/(tw)) > ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

 

""" ,
"""   """).item()

    latex_content_trecho_V= np.where((P < 0) & (((t3-2*tf)/(tw)) <= ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

O valor limite para esbeltez da mesa é:\\

$$(b/t)_<lim> = 0.56\sqrt<\frac<E><f_y>> = 0.56\sqrt<\frac<{E1}*10^9 ><{Fy_x}*10^6 >> = {bt_lim_inf_grupo_04}$$

\vspace<0.3cm>


A relação entre esbeltez da mesa e o valor limite é:\\

\centerline <$\displaystyle \frac<(0.5b)><t_f> \leq \frac<(b/t)_<lim>><\sqrt<\chi>>$ \( \Rightarrow  \) 
$\displaystyle \frac<(0.5*{t2})><{tf}> \leq \frac<{bt_lim_inf_grupo_04}><\sqrt<{chi}>>$>

\vspace<.3cm>

Como a esbeltez da mesa é menor ou igual do que o valor limite, a \textbf<largura efetiva da mesa> é dada por:\\
$$b_<ef,mesa> = (0.5b) = (0.5*{t2}) = {b_ef_mesa_sup}m$$

\vspace<0.3cm>

""",
"""   """).item()

    latex_content_trecho_W= np.where((P < 0) & (((t3-2*tf)/(tw)) > ((bt_lim_inf_grupo_02)/(chi**0.5))) , rf"""

O valor limite para esbeltez da mesa é:\\

$$(b/t)_<lim> = 0.56\sqrt<\frac<E><f_y>> = 0.56\sqrt<\frac< {E1}*10^9 >< {Fy_x}*10^6 >> = {bt_lim_inf_grupo_04}$$

\vspace<0.3cm>

A relação entre esbeltez da mesa e o valor limite é:\\

\centerline <$\displaystyle \frac<(0.5b)><t_f> \textgreater \frac<(b/t)_<lim>><\sqrt<\chi>>$ \( \Rightarrow  \) 
$\displaystyle \frac<(0.5*{t2})><{tf}> \textgreater \frac<{bt_lim_inf_grupo_04}><\sqrt<{chi}>>$>

\vspace<.3cm>

Como a esbeltez da alma é maior do que o valor limite, a \textbf<largura efetiva da mesa> é dada por:\\

$$\sigma_<el> = \left(1.49<\frac<<(b/t)_<lim>>><(0.5b)/t_f>>\right)^2 f_y = {sigma_el_mesa_sup}kN.m$$

\vspace<0.3cm>

$$b_<ef,alma>=(0.5b)\left(1-0.22<\sqrt<\frac<\sigma_<el>><\chi f_y>>>\right) \sqrt<\frac<\sigma_<el>><\chi f_y>> = {b_ef_mesa_sup}m$$

\vspace<1cm>

""" ,
"""   """).item()

    latex_content_trecho_X= np.where( P < 0 , rf"""

Com as larguras efetivas da alma e das mesas, basta determinar a Área Efetiva da Seção Transversal da Barra ($A_<ef>$) como sendo o somatório da multiplicação 
das larguras efetiva pela as respectivas espessuras. Sendo assim:

$$A_<ef> = b_<ef,alma>.t_w + 4.(b_<ef,mesa>.t_f) = {b_ef_alma}*{tw} + 4*({b_ef_mesa_sup}*{tf}) = {Area_ef}*10^<-4> m^2$$
\\

""" , 
"""   """).item()

    latex_content_trecho_Y= np.where( P < 0 , rf"""

\subsubsection<Força Axial de Compressão Resistente>
Ao final, com todos os parâmetros necessários definidos, basta aplicar a equação do item 5.3.2 da NBR8800:2024. 
A força axial de compressão resistente de cálculo de uma barra, associada aos estados-limite
últimos de instabilidade por flexão, por torção ou flexo-torção, e de instabilidade local, deve ser
determinada pela equação:

$$N_<c,Rd> = \frac<\chi A_<ef> f_y><\gamma_<a1>> = \frac<{chi}*({Area_ef}*10^<-4>)*({Fy_x}*10^6) ><{gamma_a1}> = {N_Rd}kN $$
\\[15pt]

""" ,
"""   """).item()

    latex_content_trecho_Z= np.where( P >= 0 , rf"""

\subsection<Força Axial de Tração Resistente>
A força axial de tração resistente de cálculo, $N_<t,Rd>$, a ser usada no dimensionamento, 
considera os estados-limite últimos de escoamento da seção bruta, de acordo com as equação indicada a seguir:
\\

$$N_<t,Rd> = \frac<A_gf_y><\gamma_<a1>> = \frac<{Area}*{Fy_x}*10^6 ><{gamma_a1}> = {N_et_1} kN $$
\\
\\

""" , 
"""   """).item()

    latex_content_trecho_AA= rf"""

ATENÇÃO:\\
Deve ser feita uma verificação mais detalhada caso o ponto selecionado seja uma região de ligação.
\\
\\
\\

"""

    latex_content_trecho_AB= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\subsection<Momento Fletor em Relação ao Eixo de Maior Inércia>
Para verificação do momento fletor resistente segundo a NBR8800:2024, deve-se seguir o procedimento estabelecido no Anexo D . Segundo este Anexo, 
o momento fletor resistente de cálculo nos estado-limite FLT, FLM e FLA, 
para as seções I e H com dois eixos de simetria e não sujeitas a momento de torção e fletida em relação aos dois eixos de inércia principais, 
é calculado conforme as condições a seguir: 
\\
\\
a) para $\lambda \leq \lambda_p$:
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<pl>$$
\\
\\
b) para $\lambda_p \textless \lambda \leq \lambda_r$:
$$M_<Rd> = \frac<1><\gamma_<a1>> \left( M_<pl> - (M_<pl> - M_r) \frac<\lambda - \lambda_p><\lambda_r - \lambda_p> \right)$$ 
\\
\\
c) para $\lambda \textgreater \lambda_r$:
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<cr>$$ \\
Sendo:\\
FLA flambagem local da alma;\\
FLM flambagem local da mesa comprimida;\\
FLT flambagem lateral com torção;\\
$M_<Rd>$ é o Momento Fletor Resistente de Cálculo;\\
$M_<pl>$ é o Momento Fletor de Plastificação da Seção Transversal, igual ao produto do 
módulo de resistência plástico ($Z$) pela resistência ao escoamento do aço ($f_y$);\\
$M_r$ é o Momento Fletor correspondente ao início do escoamento, incluindo a influência 
das tensões residuais em alguns casos;\\
$\lambda$ é o parâmetro de esbeltez;\\
$\lambda_p$ é o parâmetro de esbeltez correspondente à plastificação;\\
$\lambda_r$ é o parâmetro de esbeltez correspondente ao início do escoamento.\\

""",
"""   """).item()

    latex_content_trecho_AC= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\subsubsection<Flambagem Lateral com Torção (FLT)>

Conforme tabela D.1 da NBR8800:2024, é preciso determinar os seguintes parâmetros:
Momento Fletor correspondente ao início do escoamento,
Momento Fletor Crítico,
Parâmetro de Esbeltez, 
Parâmetro de Esbeltez correspondente à Plastificação, 
Parâmetro de Esbeltez correspondente ao início do Escoamento e 
Momento Fletor de Plastificação da Seção Transversal.


""",
"""   """).item()

    latex_content_trecho_AD= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""


\paragraph<Momento Fletor correspondente ao início do escoamento>
A expressão que determina o Momento Fletor correspondente ao início do escoamento:\\

$$M_r = (f_y-\sigma_r).W_x$$\\ 
Sendo que a tensão residual de compressão nas mesas, $\sigma_r$, deve ser considerada igual 
a 30\% da resistência ao escoamento do aço utilizado.
$$M_r = (f_y-\sigma_r).W_x = 0.7 * ({Fy_x}*10^6) * ({S33_cm}*10^<-6>) = {M_r_tipo_1_FLT}kN.m$$\\ 
\\


""",
"""   """).item()

    latex_content_trecho_AE= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""


\paragraph<Momento Fletor Crítico>
\\
A expressão que determina o Momento Fletor Crítico:


$$M_<cr> = \frac<C_b.\pi^2.E.I_x><L_b^2>\sqrt<\frac<C_w><I_x>(1+0.039.\frac<JL_b^2><C_w>)>$$\\

Sendo que:\\
$C_b$ é o fator de modificação para diagrama de momento fletor não uniforme, que pode ser calculado conforme 
itens 5.4.2.3, 5.4.2.4 e 5.4.2.5 da NBR8800:2024. Contudo, para este dimensionamento, será adotado igual a 1.\\
$C_w$ é a constante de empenamento da seção transversal. Para perfis I e H, o cálculo de é conforme a expressão:

$$C_w = \frac<I_y(d-t_f)^2><4> = \frac< ({I22_cm}*10^<-8>) * ({t3}-{tf})^2 ><4> = {C_w}*10^<-7>m^6$$\\

Assim, aplicando os valores de $C_b$ e $C_w$ obtidos, têm-se:

$$M_<cr> = \frac<C_b. \pi^2.E.I_x><L_b^2>\sqrt<\frac<C_w><I_x>(1+0.039.\frac<JL_b^2><C_w>)> = $$
$$M_<cr> = \frac<{C_b} * 3.1415^2 * ({E1}*10^9) * ({I33_cm}*10^<-8>) >< ({XLMajor}*{Length})^2>*\sqrt<\frac<{C_w}*10^<-7>><{I33_cm}*10^<-8>>*(1 + 0.039 * \frac<({TorsConst_cm}*10^<-8>)*({XLMajor}*{Length})^2><{C_w}*10^<-7>>)>$$\\
$$M_<cr> = {M_cr_tipo_1_FLT}kN.m$$\\
\\


""",
"""   """).item()

    latex_content_trecho_AF= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez>
\\
A expressão que determina o Parâmetro de Esbeltez:

$$\lambda = \frac<L_b><r_x> = \frac<{XLMajor}*{Length}><{R33}> = {lambda_tipo_1_FLT}$$\\
\\

""",
"""   """).item()

    latex_content_trecho_AG= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente à Plastificação>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente à Plastificação:

$$\lambda_p = 1.76\sqrt<\frac<E><f_y>> = 1.76*\sqrt<\frac< {E1}*10^9 >< {Fy_x}*10^6 >> = {lambda_p_tipo_1_FLT} $$\\
\\

""",
"""   """).item()

    latex_content_trecho_AH= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente ao início do Escoamento>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente ao início do Escoamento:

$$\lambda_r = \frac<1.38.C_b.\sqrt<I_x.J>><r_x.J.\beta_1>\sqrt<1+\sqrt<1+\frac<27.C_w.\beta_1^2><C_b^2.I_x>>>$$\\


Sendo que:\\
$$\beta_1 = \frac<(f_y-\sigma_r).W_x><E.J> = \frac< 0.7 * ({Fy_x}*10^6) * ({S33_cm}*10^<-6>) >< ({E1}*10^9) * ({TorsConst_cm}*10^<-8>) > = {beta_1}$$\\

Assim, aplicando o valor de $\beta_1$ obtido, têm-se:

$$\lambda_r = \frac<1.38 * {C_b}*\sqrt< ({I33_cm}*10^<-8>) * ({TorsConst_cm}*10^<-8>) > >< {R33} * ({TorsConst_cm}*10^<-8>) * {beta_1} >. \sqrt< 1 + \sqrt< 1 + \frac< 27 * ({C_w}*10^<-7>) * {beta_1}^2 >< {C_b}^2 * ({I33_cm}*10^<-8>) >>> = {lambda_r_tipo_1_FLT} $$\\
\\

""",
"""   """).item()

    latex_content_trecho_AI= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Momento Fletor de Plastificação da Seção Transversal>
\\
A expressão que determina o Momento Fletor de Plastificação da Seção Transversal:


$$M_<pl>= Z_x.f_y = ({Z33_cm}*10^<-6>) * ({Fy_x}*10^6) = {M_pl_tipo_1_FLT}kN.m$$


""",
"""   """).item()

    latex_content_trecho_AJ= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( lambda_tipo_1_FLT <= lambda_p_tipo_1_FLT , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLT>
\\
Como: $\lambda = {lambda_tipo_1_FLT}$; $\lambda_p = {lambda_p_tipo_1_FLT}$ e $\lambda_r = {lambda_r_tipo_1_FLT}$.\\
Então $\lambda \leq \lambda_p$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<pl> = \frac<1><{gamma_a1}>*{M_pl_tipo_1_FLT} = {M_Rd_tipo_1_FLT}kN.m$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_AK= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( (lambda_p_tipo_1_FLT < lambda_tipo_1_FLT) & (lambda_tipo_1_FLT <= lambda_r_tipo_1_FLT) , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLT>
\\
Como: $\lambda = {lambda_tipo_1_FLT}$; $\lambda_p = {lambda_p_tipo_1_FLT}$ e $\lambda_r = {lambda_r_tipo_1_FLT}$\\
Então $\lambda_p \textless \lambda \leq \lambda_r$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>> \left( M_<pl> - (M_<pl> - M_r) \frac<\lambda - \lambda_p><\lambda_r - \lambda_p> \right)$$ 
$$M_<Rd> = \frac<1><{gamma_a1}> \left( {M_pl_tipo_1_FLT} - ({M_pl_tipo_1_FLT} - {M_r_tipo_1_FLT}) \frac<{lambda_tipo_1_FLT} -
 {lambda_p_tipo_1_FLT}><{lambda_r_tipo_1_FLT} - {lambda_p_tipo_1_FLT}> \right) = {M_Rd_tipo_1_FLT}kN.m$$ 
\\

""" ,
""" """).item()
,
"""   """).item()

    latex_content_trecho_AL= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( lambda_tipo_1_FLT > lambda_r_tipo_1_FLT , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLT>
\\
Como: $\lambda = {lambda_tipo_1_FLT}$ ; $\lambda_p = {lambda_p_tipo_1_FLT}$ e $\lambda_r = {lambda_r_tipo_1_FLT}$\\
Então $\lambda \textgreater \lambda_r$.
\\
Sendo assim:
$$M_<Rd> = \frac<1><\gamma_<a1>> M_<cr> = \frac<1><{gamma_a1}> * {M_cr_tipo_1_FLT} = {M_Rd_tipo_1_FLT}kN.m $$
\\

\vspace<1cm>

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_AM= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\subsubsection<Flambagem Local da Mesa Comprimida (FLM)>

Conforme tabela D.1 da NBR8800:2024, é preciso determinar os seguintes parâmetros: 
Momento Fletor correspondente ao início do escoamento, 
Momento Fletor Crítico,
Parâmetro de Esbeltez, 
Parâmetro de Esbeltez correspondente à Plastificação,
Parâmetro de Esbeltez correspondente ao início do Escoamento e 
Momento Fletor de Plastificação da Seção Transversal.
\\
\\

""",
"""   """).item()

    latex_content_trecho_AN= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Momento Fletor correspondente ao início do escoamento>
\\
A expressão que determina o Momento Fletor correspondente ao início do escoamento:


$$M_r = (f_y-\sigma_r).W_x$$\\ 
Sendo que a tensão residual de compressão nas mesas, $\sigma_r$, deve ser considerada igual 
a 30\% da resistência ao escoamento do aço utilizado.
$$M_r = (f_y-\sigma_r).W_x = 0.7 * ({Fy_x}*10^6) * ({S33_cm}*10^<-6>) = {M_r_tipo_1_FLM}kN.m$$\\ 
\\

""",
"""   """).item()

    latex_content_trecho_AO= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Momento Fletor Crítico>

$$M_<cr> = \frac<0.69E><\lambda^2>W_c$$
\\
\\
Onde:\\
$W_c$ é o módulo de resistência elástico do lado comprimido da seção, relativo ao eixo de flexão;\\
$\lambda=b/t$ é, conforme item D.2.8-h) da NBR8800:2024, a relação entre largura e espessura aplicável à mesa do perfil.
\\

Para o calculo de $W_c$, têm-se a expressão:

$$W_c = \frac<\frac<b_f.t_f^3><12> + (b_f.t_f).(\frac<h><2>-\frac<t_f><2>)^2 + \frac<t_w.(\frac<h><2> - t_f)^3><3>><\frac<h><2>>$$

$$W_c = \frac<\frac<{t2}*{tf}^3><12> + ({t2}*{tf}).(\frac<{t3}><2>-\frac<{tf}><2>)^2 + \frac<{tw}.(\frac<{t3}><2> - {tf})^3><3>><\frac<{t3}><2>> = {W_x_c}*10^<-6>m^3 $$


Assim, aplicando os valores de $W_c$ e $\lambda$ obtidos, têm-se:

$$M_<cr> = \frac<0.69.E><\lambda^2>W_c = \frac< 0.69 * ({E1}*10^9) >< (\frac< {t2}/2 >< {tf} >)^2>*({W_x_c}*10^<-6>) = {M_cr_tipo_1_FLM}kN.m$$\\
\\


""",
"""   """).item()

    latex_content_trecho_AP= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez>
\\
A expressão que determina o Parâmetro de Esbeltez:

$$\lambda = \frac<b><t> = \frac<{t2}/2><{tf}> = {lambda_tipo_1_FLM}$$\\
\\


""",
"""   """).item()

    latex_content_trecho_AQ= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente à Plastificação>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente à Plastificação:

$$\lambda_p = 0.38\sqrt<\frac<E><f_y>> = 0.38 * \sqrt<\frac< ({E1}*10^9) >< ({Fy_x}*10^6) >> = {lambda_p_tipo_1_FLM} $$\\
\\


""",
"""   """).item()

    latex_content_trecho_AR= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente ao início do Escoamento>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente ao início do Escoamento:

$$\lambda_r = 0.83 \sqrt<\frac<E><(f_y - \sigma_r)>> = 0.83 * \sqrt<\frac< ({E1}*10^9) >< 0.7 * ({Fy_x}*10^6) >> = {lambda_r_tipo_1_FLM}$$\\
\\


""",
"""   """).item()

    latex_content_trecho_AS= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Momento Fletor de Plastificação da Seção Transversal>
\\
A expressão que determina o Momento Fletor de Plastificação da Seção Transversal:

$$M_<pl>= Z.f_y = ({Z33_cm}*10^<-6>) * ({Fy_x}*10^6) = {M_pl_tipo_1_FLM}kN.m$$\\
\\


""",
"""   """).item()

    latex_content_trecho_AT= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( lambda_tipo_1_FLM <= lambda_p_tipo_1_FLM , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLM>
\\
Como: $\lambda = {lambda_tipo_1_FLM}$; $\lambda_p = {lambda_p_tipo_1_FLM}$ e $\lambda_r = {lambda_r_tipo_1_FLM}$.\\
Então $\lambda \leq \lambda_p$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<pl> = \frac<1><{gamma_a1}>*{M_pl_tipo_1_FLM} = {M_Rd_tipo_1_FLM}kN.m$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_AU= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( (lambda_p_tipo_1_FLM < lambda_tipo_1_FLM) & (lambda_tipo_1_FLM <= lambda_r_tipo_1_FLM) , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLM>
\\
Como: $\lambda = {lambda_tipo_1_FLM}$; $\lambda_p = {lambda_p_tipo_1_FLM}$ e $\lambda_r = {lambda_r_tipo_1_FLM}$\\
Então $\lambda_p \textless \lambda \leq \lambda_r$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>> \left( M_<pl> - (M_<pl> - M_r) \frac<\lambda - \lambda_p><\lambda_r - \lambda_p> \right)$$ 
$$M_<Rd> = \frac<1><{gamma_a1}> \left( {M_pl_tipo_1_FLM} - ({M_pl_tipo_1_FLM} - {M_r_tipo_1_FLM}) \frac<{lambda_tipo_1_FLM} -
 {lambda_p_tipo_1_FLM}><{lambda_r_tipo_1_FLM} - {lambda_p_tipo_1_FLM}> \right) = {M_Rd_tipo_1_FLM}kN.m$$ 
\\


""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_AV= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( lambda_tipo_1_FLM > lambda_r_tipo_1_FLM , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLM>
\\
Como: $\lambda = {lambda_tipo_1_FLM}$ ; $\lambda_p = {lambda_p_tipo_1_FLM}$ e $\lambda_r = {lambda_r_tipo_1_FLM}$\\
Então $\lambda \textgreater \lambda_r$.
\\
Sendo assim:
$$M_<Rd> = \frac<1><\gamma_<a1>> M_<cr> = \frac<1><{gamma_a1}> * {M_cr_tipo_1_FLM} = {M_Rd_tipo_1_FLM}kN.m$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_AW= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\subsubsection<Flambagem Local da Alma (FLA)>

Conforme tabela D.1 da NBR8800:2024, é preciso determinar os seguintes parâmetros:
Momento Fletor correspondente ao início do escoamento,
Momento Fletor Crítico,
Parâmetro de Esbeltez,
Parâmetro de Esbeltez correspondente à Plastificação,
Parâmetro de Esbeltez correspondente ao início do Escoamento e
Momento Fletor de Plastificação da Seção Transversal.
\\
\\

""",
"""   """).item()

    latex_content_trecho_AX= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Momento Fletor correspondente ao início do escoamento>
\\
A expressão que determina o Momento Fletor correspondente ao início do escoamento:


$$M_r = f_y.W_x = ({Fy_x}*10^6) * ({S33_cm}*10^<-6>) = {M_r_tipo_1_FLA}kN.m$$\\ 
\\

""",
"""   """).item()

    latex_content_trecho_AY= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Momento Fletor Crítico>
\\
A expressão que determina o Momento Fletor Crítico:

É necessário o uso do Anexo E da NBR8800:2024 para determinação do Momento Fletor Crítico de vigas de alma Esbelta. 
Como esta memória se limita a verificação de perfil laminados, que não se enquadra neste caso, então é dispensada a análise segundo o Anexo E.\\
\\

""",
"""   """).item()

    latex_content_trecho_AZ= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez>
\\
A expressão que determina o Parâmetro de Esbeltez:

$$\lambda = \frac<h><t_w> = \frac<{t3}-{tf}-{tfb}><{tw}> = {lambda_tipo_1_FLA}$$\\
\\
Onde:\\
$h$ é igual a esse valor menos os dois raios de concordância entre a mesa e a alma nos perfis laminados;\\
$t_w$ é a espessura da alma.\\
\\

""",
"""   """).item()

    latex_content_trecho_BA= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente à Plastificação>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente à Plastificação:


$$\lambda_p = 3.76\sqrt<\frac<E><f_y>> = 3.76 * \sqrt<\frac< {E1}*10^9 >< {Fy_x}*10^6 >> = {lambda_p_tipo_1_FLA} $$\\
\\

""",
"""   """).item()

    latex_content_trecho_BB= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente ao início do Escoamento>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente ao início do Escoamento:

$$\lambda_r = 5.7 \sqrt<\frac<E><f_y>> = 5.7 * \sqrt<\frac< {E1}*10^9 >< {Fy_x}*10^6 >> = {lambda_r_tipo_1_FLA}$$\\
\\

""",
"""   """).item()

    latex_content_trecho_BC= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\paragraph<Momento Fletor de Plastificação da Seção Transversal>
\\
A expressão que determina o Momento Fletor de Plastificação da Seção Transversal:

$$M_<pl>= Z.f_y = ({Z33_cm}*10^<-6>) * ({Fy_x}*10^6) = {M_pl_tipo_1_FLA}kN.m $$\\
\\

""",
"""   """).item()

    latex_content_trecho_BD= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( lambda_tipo_1_FLA <= lambda_p_tipo_1_FLA , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLA>
\\
Como: $\lambda = {lambda_tipo_1_FLA}$; $\lambda_p = {lambda_p_tipo_1_FLA}$ e $\lambda_r = {lambda_r_tipo_1_FLA}$.\\
Então $\lambda \leq \lambda_p$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<pl> = \frac<1><{gamma_a1}>*{M_pl_tipo_1_FLA} = {M_Rd_tipo_1_FLA}kN.m$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_BE= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( (lambda_p_tipo_1_FLA < lambda_tipo_1_FLA) & (lambda_tipo_1_FLA <= lambda_r_tipo_1_FLA) , rf"""

\paragraph<Momento Fletor Resistente de Cálculo segundo FLA>
\\
Como: $\lambda = {lambda_tipo_1_FLA}$; $\lambda_p = {lambda_p_tipo_1_FLA}$ e $\lambda_r = {lambda_r_tipo_1_FLA}$\\
Então $\lambda_p \textless \lambda \leq \lambda_r$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>> \left( M_<pl> - (M_<pl> - M_r) \frac<\lambda - \lambda_p><\lambda_r - \lambda_p> \right)$$ 
$$M_<Rd> = \frac<1><{gamma_a1}> \left( {M_pl_tipo_1_FLA} - ({M_pl_tipo_1_FLA} - {M_r_tipo_1_FLA}) \frac<{lambda_tipo_1_FLA} -
 {lambda_p_tipo_1_FLA}><{lambda_r_tipo_1_FLA} - {lambda_p_tipo_1_FLA}> \right) = {M_Rd_tipo_1_FLA}$$ 
\\

""" ,
"""   """).item(),
"""   """).item()

    latex_content_trecho_BF= np.where ( (M3 < -0.1) | (M3 > 0.1) , np.where ( lambda_tipo_1_FLA > lambda_r_tipo_1_FLA , rf"""


\paragraph<Momento Fletor Resistente de Cálculo segundo FLA>
\\
Como: $\lambda = {lambda_tipo_1_FLA}$ ; $\lambda_p = {lambda_p_tipo_1_FLA}$ e $\lambda_r = {lambda_r_tipo_1_FLA}$\\
Então $\lambda \textgreater \lambda_r$.
\\
Sendo assim, o perfil utilizado tem alma esbelta e deve ser verificado conforme Anexo E da NBR8800:2024.

""" ,
"""   """).item(),
"""   """).item()

    latex_content_trecho_BG= np.where ( (M3 < -0.1) | (M3 > 0.1) , rf"""

\subsubsection<Momento Fletor Resistente de Cálculo>
O Momento Fletor Resistente de Cálculo é o menor valor entre:\\
a) Momento Fletor Resistente de Cálculo segundo FLT;\\
b) Momento Fletor Resistente de Cálculo segundo FLM;\\
c) Momento Fletor Resistente de Cálculo segundo FLA.\\

Como os valores são: \\
${M_Rd_tipo_1_FLT} kN.m$ para Momento Fletor Resistente de Cálculo segundo FLT;\\
${M_Rd_tipo_1_FLM} kN.m$ para Momento Fletor Resistente de Cálculo segundo FLM;\\
${M_Rd_tipo_1_FLA} kN.m$ para Momento Fletor Resistente de Cálculo segundo FLA.\\


Então o Momento Fletor Resistente de Cálculo para o eixo de maior inércia é ${M_Rd_tipo_1} kN.m$.\\

""",
"""   """).item()

    latex_content_trecho_BH= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\subsection<Momento Fletor em Relação ao Eixo de Menor Inércia>
Para verificação do momento fletor resistente segundo a NBR8800:2024, deve-se seguir o procedimento estabelecido no Anexo D.
Segundo este Anexo, o momento fletor resistente de cálculo nos estado-limite FLM, 
para as seções I e H com dois eixos de simetria e não sujeitas a momento de torção, 
fletida em relação aos dois eixos de inércia principais, 
é calculado conforme as condições a seguir: 
\\
\\
a) para $\gamma \leq \gamma_p$:
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<pl>$$
\\
\\
b) para $\lambda_p \textless \lambda \leq \lambda_r$:
$$M_<Rd> = \frac<1><\gamma_<a1>> \left( M_<pl> - (M_<pl> - M_r) \frac<\lambda - \lambda_p><\lambda_r - \lambda_p> \right)$$ 
\\
\\
c) para $\gamma \textgreater \gamma_r$:
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<cr>$$ \\
Sendo:\\
FLM flambagem local da mesa comprimida;\\
$M_<Rd>$ é o Momento Fletor Resistente de Cálculo;\\
$M_<pl>$ é o Momento Fletor de Plastificação da Seção Transversal, igual ao produto do módulo de resistência plástico ($Z$) 
pela resistência ao escoamento do aço ($f_y$);\\
$M_r$ é o Momento Fletor correspondente ao início do escoamento, incluindo a influência das tensões residuais em alguns casos;\\
$\lambda$ é o parâmetro de esbeltez;\\
$\lambda_p$ é o parâmetro de esbeltez correspondente à plastificação;\\
$\lambda_r$ é o parâmetro de esbeltez correspondente ao início do escoamento.\\

Vale lembrar que para flexão no eixo de menor inércia, a tabela D.1 não aponta para uma verificação para o FLT, 
bastando apenas a verificação do FLM e FLA. Como esta memória verifica apenas perfis com seções tipo I e H, é 
dispensada a verificação do FLA. A verificação do FLA é apenas aplicável para verificação de perfis do tipo U.\\

\vspace<1cm>

""",
"""   """).item()

    latex_content_trecho_BI= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\subsubsection<Flambagem Local da Mesa Comprimida (FLM)>

Conforme tabela D.1 da NBR8800:2024, é preciso determinar os seguintes parâmetros:\\
\\

""",
"""   """).item()

    latex_content_trecho_BJ= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\paragraph<Momento Fletor correspondente ao início do escoamento>
\\
A expressão que determina o Momento Fletor correspondente ao início do escoamento:


$$M_r = (f_y-\sigma_r).W_y$$\\ 
Sendo que a tensão residual de compressão nas mesas, $\sigma_r$, deve ser considerada igual 
a 30\% da resistência ao escoamento do aço utilizado.
$$M_r = (f_y-\sigma_r).W_y = 0.7 * ({Fy_x}*10^6) * ({S22_cm}*10^<-6>) = {M_r_tipo_3_FLM}kN.m$$\\ 
\\

""",
"""   """).item()

    latex_content_trecho_BK= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\paragraph<Momento Fletor Crítico>
\\
A expressão que determina o Momento Fletor Crítico:


$$M_<cr> = \frac<0.69E><\lambda^2>W_c$$
\\
\\
Onde:\\
$W_c$ é o módulo de resistência elástico do lado comprimido da seção, relativo ao eixo de flexão;\\
$\lambda=b/t$ é, conforme item D.2.8-h) da NBR8800:2024, a relação entre largura e espessura aplicável à mesa do perfil.
\\

Para o calculo de $W_c$, têm-se a expressão:

$$W_c = \frac<t_f.(\frac<b_f><2>)^3><3> + \frac<(h-2.t_f).(\frac<t_w><2>)^3><3> + \frac<t_f.(\frac<b_f><2>)^3><3>

$$W_c = \frac<{tf}*(\frac<{t2}><2>)^3><3> + \frac<({t3}-2*{tf}).(\frac<{tw}><2>)^3><3> + \frac<{tfb}.(\frac<{t2b}><2>)^3><3> = {W_y_esq}*10^<-6>m^3
\\
\\

Assim, aplicando os valores de $W_c$ e $\lambda$ obtidos, têm-se:

$$M_<cr> = \frac<0.69.E><\lambda^2>W_c = \frac< 0.69 * ({E1}*10^9) >< ( \frac< {t2}/2 >< {tf} >)^2> * ({W_y_esq}*10^<-6>) = {M_cr_tipo_3_FLM}kN.m$$\\
\\

""",
"""   """).item()

    latex_content_trecho_BL= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez>
\\
A expressão que determina o Parâmetro de Esbeltez:


$$\lambda = \frac<b><t> = \frac<{t2}/2><{tf}> = {lambda_tipo_3_FLM}$$\\
\\

""",
"""   """).item()

    latex_content_trecho_BM= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente à Plastificação>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente à Plastificação:


$$\lambda_p = 0.38\sqrt<\frac<E><f_y>> = 0.38*\sqrt<\frac< {E1}*10^9 >< {Fy_x}*10^6 >> = {lambda_p_tipo_3_FLM} $$\\
\\

""",
"""   """).item()

    latex_content_trecho_BN= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\paragraph<Parâmetro de Esbeltez correspondente ao início do Escoamento>
\\
A expressão que determina o Parâmetro de Esbeltez correspondente ao início do Escoamento:

$$\lambda_r = 0.83 \sqrt<\frac<E><(f_y - \sigma_r)>> = 0.83 * \sqrt< \frac< {E1}*10^9 >< 0.7 * ({Fy_x}*10^6) >> = {lambda_r_tipo_3_FLM}$$\\
\\

""",
"""   """).item()

    latex_content_trecho_BO= np.where ( (M2 < -0.1) | (M2 > 0.1) , rf"""

\paragraph<Momento Fletor de Plastificação da Seção Transversal>
\\
A expressão que determina o Momento Fletor de Plastificação da Seção Transversal:

$$M_<pl>= Z.f_y = ({Z22_cm}*10^<-6>) * ({Fy_x}*10^6) = {M_pl_tipo_3_FLM}kN.m $$\\


""",
"""   """).item()

    latex_content_trecho_BP= np.where ( (M2 < -0.1) | (M2 > 0.1) , np.where ( lambda_tipo_3_FLM <= lambda_p_tipo_3_FLM , rf"""

\paragraph<Momento Fletor Resistente de Cálculo>
\\
Como: $\lambda = {lambda_tipo_3_FLM}$; $\lambda_p = {lambda_p_tipo_3_FLM}$ e $\lambda_r = {lambda_r_tipo_3_FLM}$.\\
Então $\lambda \leq \lambda_p$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>>M_<pl> = \frac<1><{gamma_a1}>*{M_pl_tipo_3_FLM} = {M_Rd_tipo_3_FLM}kN.m$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_BQ= np.where ( (M2 < -0.1) | (M2 > 0.1) , np.where ( (lambda_p_tipo_3_FLM < lambda_tipo_3_FLM) & (lambda_tipo_3_FLM <= lambda_r_tipo_3_FLM) , rf"""

\paragraph<Momento Fletor Resistente de Cálculo>
\\
Como: $\lambda = {lambda_tipo_3_FLM}$; $\lambda_p = {lambda_p_tipo_3_FLM}$ e $\lambda_r = {lambda_r_tipo_3_FLM}$\\
Então $\lambda_p \textless \lambda \leq \lambda_r$.
\\
Sendo assim: 
$$M_<Rd> = \frac<1><\gamma_<a1>> \left( M_<pl> - (M_<pl> - M_r) \frac<\lambda - \lambda_p><\lambda_r - \lambda_p> \right)$$ 
$$M_<Rd> = \frac<1><{gamma_a1}> \left( {M_pl_tipo_3_FLM} - ({M_pl_tipo_3_FLM} - {M_r_tipo_3_FLM}) \frac<{lambda_tipo_3_FLM} -
 {lambda_p_tipo_3_FLM}><{lambda_r_tipo_3_FLM} - {lambda_p_tipo_3_FLM}> \right) = {M_Rd_tipo_3_FLM}kN.m$$ 
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_BR= np.where ( (M2 < -0.1) | (M2 > 0.1) , np.where ( lambda_tipo_3_FLM > lambda_r_tipo_3_FLM , rf"""

\paragraph<Momento Fletor Resistente de Cálculo>
\\
Como: $\lambda = {lambda_tipo_3_FLM}$ ; $\lambda_p = {lambda_p_tipo_3_FLM}$ e $\lambda_r = {lambda_r_tipo_3_FLM}$\\
Então $\lambda \textgreater \lambda_r$.
\\
Sendo assim:
$$M_<Rd> = \frac<1><\gamma_<a1>> M_<cr> = \frac<1><{gamma_a1}> * {M_cr_tipo_3_FLM} = {M_Rd_tipo_3_FLM}kN.m $$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_BS= np.where ( (V2 < -0.1) | (V2 > 0.1) , rf"""

\subsection<Força Cortante Resistente de Cálculo>

\subsubsection<Esforços de Cisalhamento na direção paralela a Alma >
Para seções I e H fletidas em relação ao eixo central de inércia perpendicular à alma
(eixo de maior momento de inércia), a força cortante resistente de cálculo, VRd, é calculada conforme
a seguir:\\
\\
a) para $\lambda \leq \lambda_p$:
$$V_<Rd> = \frac<V_pl><\gamma_<a1>>$$
\\
b) para $\lambda_p \textless \lambda \leq \lambda_r$:
$$V_<Rd> = \frac<\lambda_p . V_<pl>><\lambda . \gamma_<a1>>$$
\\
c) para $\lambda \textgreater \lambda_r$:
$$V_<Rd> = 1.24 \left( \frac<\lambda_p><\lambda> \right)^2 \frac<V_<pl>><\gamma_<a1>>$$
\\
Onde:\\
$\lambda = \frac<h><t_w>$ é o parâmetro de esbeltez;\\
$\lambda_p = 1.1\sqrt<\frac<k_vE><f_y>>$ é o parâmetro de esbeltez correspondente à plastificação;\\
$\lambda_r = 1.37\sqrt<\frac<k_vE><f_y>>$ é o parâmetro de esbeltez correspondente ao início do escoamento;\\
$k_v=5.34$ para almas sem enrijecedores transversais;\\
$V_<pl> = 0.6.A_w.f_y$ é a força cortante correspondente à plastificação da alma por cisalhamento;\\
$h$ é a altura da alma considerando o trecho reto das faces da alma, ou seja, é a altura do perfil subtraindo 
as duas espessuras das mesas e os dois raios de conformação entre a alma e mesas do perfil;\\
$A_w = d.t_w$ é a área efetiva de cisalhamento;\\
$d$ é a altura total da seção transversal;\\
$t_w$ é a espessura da alma.

""" ,
"""   """).item()

    latex_content_trecho_BT= np.where ( (V2 < -0.1) | (V2 > 0.1) , rf"""

$$\lambda = \frac<h><t_w> = \frac<{t3} - {tf} - {tfb}><{tw}> = {lambda_V_Rd_vert}$$
\\
$$\lambda_p = 1.1\sqrt<\frac<k_vE><f_y>> = 1.1 * \sqrt< \frac<{k_v_vert} * ({E1}*10^9) >< {Fy_x}*10^6 > > = {lambda_p_V_Rd_vert}$$
\\
$$\lambda_r = 1.37\sqrt<\frac<k_vE><f_y>> = 1.37 * \sqrt< \frac<{k_v_vert} * ({E1}*10^9) >< {Fy_x}*10^6 > > = {lambda_r_V_Rd_vert}$$
\\
$$V_<pl> = 0.6.A_w.f_y = 0.6 * ({t3}* {tw}) * ({Fy_x}*10^6) = {V_pl_vert} kN$$
\\
\\

""" ,
"""   """).item()

    latex_content_trecho_BU= np.where ( (V2 < -0.1) | (V2 > 0.1) ,
                                np.where ( lambda_V_Rd_vert <= lambda_p_V_Rd_vert , rf"""

Como $\lambda = {lambda_V_Rd_vert}$ ; $\lambda_p = {lambda_p_V_Rd_vert}$ e $\lambda_r = {lambda_r_V_Rd_vert}$.
\\
Então $\lambda \leq \lambda_p$:
$$V_<Rd> = \frac<V_pl><\gamma_<a1>> = \frac<{V_pl_vert}><{gamma_a1}> = {V_Rd_vert}kN$$
\\

""" ,
""""   """).item()
,
"""   """).item()

    latex_content_trecho_BV= np.where ( (V2 < -0.1) | (V2 > 0.1) ,
                                np.where ( (lambda_p_V_Rd_vert < lambda_V_Rd_vert) & (lambda_V_Rd_vert <= lambda_r_V_Rd_vert) , rf"""

Como $\lambda = {lambda_V_Rd_vert}$ ; $\lambda_p = {lambda_p_V_Rd_vert}$ e $\lambda_r = {lambda_r_V_Rd_vert}$
\\
Então $\lambda_p \textless \lambda \leq \lambda_r$:
$$V_<Rd> = \frac<\lambda_p . V_<pl>><\lambda . \gamma_<a1>> = 
\frac<{lambda_p_V_Rd_vert} * {V_pl_vert}><{lambda_V_Rd_vert} *{gamma_a1}> = {V_Rd_vert}kN$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_BX= np.where ( (V2 < -0.1) | (V2 > 0.1) ,
                                     np.where ( lambda_V_Rd_vert > lambda_r_V_Rd_vert , rf"""

Como $\lambda = {lambda_V_Rd_vert}$ ; $\lambda_p = {lambda_p_V_Rd_vert}$ e $\lambda_r = {lambda_r_V_Rd_vert}$
\\
Então $\lambda \textgreater \lambda_r$:
$$V_<Rd> = 1.24 \left( \frac<\lambda_p><\lambda> \right)^2 \frac<V_<pl>><\gamma_<a1>> =
 1.24 \left( \frac<{lambda_p_V_Rd_vert}><{lambda_V_Rd_vert}> \right)^2 \frac<{V_pl_vert}><{gamma_a1}> = {V_Rd_vert}kN$$
\\

""",
"""   """).item()
,
"""   """).item()

    latex_content_trecho_BY= np.where ( (V3 < -0.1) | (V3 > 0.1) , rf"""

\subsubsection<Esforços de Cisalhamento na direção paralela a Mesa >
Para seções I e H fletidas em relação ao eixo central de inércia perpendicular à mesa
(eixo de menor momento de inércia), a força cortante resistente de cálculo, VRd, é calculada conforme
a seguir:\\
\\
a) para $\lambda \leq \lambda_p$:
$$V_<Rd> = \frac<V_pl><\gamma_<a1>>$$
\\
b) para $\lambda_p \textless \lambda \leq \lambda_r$:
$$V_<Rd> = \frac<\lambda_p . V_<pl>><\lambda . \gamma_<a1>>$$
\\
c) para $\lambda \textgreater \lambda_r$:
$$V_<Rd> = 1.24 \left( \frac<\lambda_p><\lambda> \right)^2 \frac<V_<pl>><\gamma_<a1>>$$
\\
Onde:\\
$\lambda = \frac<h><t_w>$ é o parâmetro de esbeltez;\\
$\lambda_p = 1.1\sqrt<\frac<k_vE><f_y>>$ é o parâmetro de esbeltez correspondente à plastificação;\\
$\lambda_r = 1.37\sqrt<\frac<k_vE><f_y>>$ é o parâmetro de esbeltez correspondente ao início do escoamento;\\
$k_v=1,2$ conforme item 5.4.3.5 da NBR8800:2024;\\
$V_<pl> = 0.6.A_w.f_y$ é a força cortante correspondente à plastificação da alma por cisalhamento;\\
$h = \frac<b_f><2>$ é igual à metade da largura das mesas nas seções I e H;\\
$t_w$ é a espessura da mesa;\\
$A_w = 2.b_f.t_w$ é a área efetiva de cisalhamento.\\
\\

""",
"""   """).item()

    latex_content_trecho_BZ= np.where ( (V3 < -0.1) | (V3 > 0.1) , rf"""

$$\lambda = \frac<h><t_w> = \frac<{t2}/2><{tf}> = {lambda_V_Rd_horz}$$
\\
$$\lambda_p = 1.1\sqrt<\frac<k_vE><f_y>> = 1.1 * \sqrt< \frac<{k_v_horz} * ({E1}*10^9) > <{Fy_x}*10^6 > > = {lambda_p_V_Rd_horz}$$
\\
$$\lambda_r = 1.37\sqrt<\frac<k_vE><f_y>> = 1.37 * \sqrt< \frac<{k_v_horz} * ({E1}*10^9) > <{Fy_x}*10^6 > > = {lambda_r_V_Rd_horz}$$
\\
$$V_<pl> = 0.6.A_w.f_y = 0.6 * 2 * ({t2}* {tf}) * ({Fy_x}*10^6) = {V_pl_horz}kN$$
\\
\\

""",
"""   """).item()

    latex_content_trecho_CA= np.where ( (V3 < -0.1) | (V3 > 0.1) , 
                                np.where ( lambda_V_Rd_horz <= lambda_p_V_Rd_horz , rf"""

Como $\lambda = {lambda_V_Rd_horz}$ ; $\lambda_p = {lambda_p_V_Rd_horz}$ e $\lambda_r = {lambda_r_V_Rd_horz}$.
\\
Então $\lambda \leq \lambda_p$:
$$V_<Rd> = \frac<V_pl><\gamma_<a1>> = \frac<{V_pl_horz}><{gamma_a1}> = {V_Rd_horz}kN$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CB= np.where ( (V3 < -0.1) | (V3 > 0.1) , 
                                np.where ( (lambda_p_V_Rd_horz < lambda_V_Rd_horz) & (lambda_V_Rd_horz <= lambda_r_V_Rd_horz) , rf"""

Como $\lambda = {lambda_V_Rd_horz}$ ; $\lambda_p = {lambda_p_V_Rd_horz}$ e $\lambda_r = {lambda_r_V_Rd_horz}$
\\
Então $\lambda_p \textless \lambda \leq \lambda_r$:
$$V_<Rd> = \frac<\lambda_p . V_<pl>><\lambda . \gamma_<a1>> = 
\frac<{lambda_p_V_Rd_horz} * {V_pl_horz}><{lambda_V_Rd_horz} *{gamma_a1}> = {V_Rd_horz}kN$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CC= np.where ( (V3 < -0.1) | (V3 > 0.1) ,
                                np.where ( lambda_V_Rd_horz > lambda_r_V_Rd_horz , rf"""

Como $\lambda = {lambda_V_Rd_horz}$ ; $\lambda_p = {lambda_p_V_Rd_horz}$ e $\lambda_r = {lambda_r_V_Rd_horz}$
\\
Então $\lambda \textgreater \lambda_r$:
$$V_<Rd> = 1.24 \left( \frac<\lambda_p><\lambda> \right)^2 \frac<V_<pl>><\gamma_<a1>> =
 1.24 \left( \frac<{lambda_p_V_Rd_horz}><{lambda_V_Rd_horz}> \right)^2 \frac<{V_pl_horz}><{gamma_a1}> = {V_Rd_horz}kN$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CD= np.where ( (M3 < -0.1) | (M3 > 0.1) | (M2 < -0.1) | (M2 > 0.1) , rf"""

\section<Resultados>
\subsection<Verificação da Combinação Esforço Axial - Flexão Principal - Flexão Secundária>
Conforme item 5.5.1.2 da NBR8800:2024, considerando que o perfil está sujeito a esforços axiais (de tração ou compressão) e momentos 
nos dois eixos principais de inércia, a verificação deve atender as seguintes expressões:\\
\\
a) para $N_<Sd>/N_<Rd> \geq 0.2$:\\
$$\frac<N_<Sd>><N_<Rd>>+\frac<8><9> \left(\frac<M_<x,Sd>><M_<x,Rd>>+\frac<M_<y,Sd>><M_<y,Rd>>\right) \leq 1.0$$
\\ 
b) para $N_<Sd>/N_<Rd> \textless 0.2$:\\
$$\frac<N_<Sd>><2N_<Rd>>+\left(\frac<M_<x,Sd>><M_<x,Rd>>+\frac<M_<y,Sd>><M_<y,Rd>>\right) \leq 1.0$$
\\
Onde:\\
$N_<Sd>$ é a força axial solicitante de cálculo;\\
$N_<Rd>$ é a força axial resistente de cálculo;\\
$M_<x,Sd>$ e $M_<y,Sd>$ são os momentos fletores solicitantes de cálculo, respectivamente, em relação aos
eixos x e y da seção transversal;\\
$M_<x,Rd>$ e $M_<y,Rd>$ são os momentos fletores resistentes de cálculo, respectivamente, em relação aos
eixos x e y da seção transversal.\\
\\

""",
"""   """).item()
    
    latex_content_trecho_CDA= np.where ( ((M3 >= -0.1) & (M3 <= 0.1)) & ((M2 >= -0.1) & (M2 <= 0.1)) , rf"""

\section<Resultados>
\subsection<Verificação Esforço Axial Simples>
Quando o perfil verificado não está simultaneamente sujeito a flexão nos dois eixos ortogonais, a verificação deve atender a seguinte expressão:\\
\\
$N_<Sd>/N_<Rd> \leq 1.0$:\\
\\
Onde:\\
$N_<Sd>$ é a força axial solicitante de cálculo;\\
$N_<Rd>$ é a força axial resistente de cálculo;\\

\\

Como $N_<Sd> = {P}$ e $N_<Rd> = {N_Rd}$, então $N_<Sd>/N_<Rd> = {N_Sd_N_Rd}$.\\

""",
"""   """).item()

    latex_content_trecho_CE= np.where ( (M3 < -0.1) | (M3 > 0.1) | (M2 < -0.1) | (M2 > 0.1) , 
                                np.where ( N_Sd_N_Rd >= 0.2 , rf"""

Como $N_<Sd> = {P}$ e $N_<Rd> = {N_Rd}$, então $N_<Sd>/N_<Rd> = {N_Sd_N_Rd}$.\\
Sendo assim, $N_<Sd>/N_<Rd> \geq 0.2$ e, consequentemente:

\vspace<0.3cm>

$$\frac<N_<Sd>><N_<Rd>>+\frac<8><9> \left(\frac<M_<x,Sd>><M_<x,Rd>>+\frac<M_<y,Sd>><M_<y,Rd>>\right) \leq 1.0$$

\vspace<0.3cm>

$$\frac<{P}><{N_Rd}>+\frac<8><9> \left(\frac<{M3}><{M_Rd_tipo_1}>+\frac<{M2}><{M_Rd_tipo_3}>\right) \leq 1.0$$

\vspace<0.3cm>

$${N_Sd_N_Rd}+\frac<8><9> \left({M_xSd_M_xRd}+{M_ySd_M_yRd}\right) \leq 1.0$$

\vspace<0.3cm>

$${Verificação_PMM} \leq 1.0$$
\\


\vspace<0.3cm>
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CF= np.where ( (M3 < -0.1) | (M3 > 0.1) | (M2 < -0.1) | (M2 > 0.1) ,
                                np.where ( N_Sd_N_Rd < 0.2 , rf"""


Como $N_<Sd> = {P}$ e $N_<Rd> = {N_Rd}$, então $N_<Sd>/N_<Rd> = {N_Sd_N_Rd}$.\\
Sendo assim, $N_<Sd>/N_<Rd> \textless 0.2$ e, consequentemente:\\

\vspace<0.3cm>

$$\frac<N_<Sd>><2N_<Rd>>+\left(\frac<M_<x,Sd>><M_<x,Rd>>+\frac<M_<y,Sd>><M_<y,Rd>>\right) \leq 1.0$$

\vspace<0.3cm>

$$\frac<{P}><2*{N_Rd}>+ \left(\frac<{M3}><{M_Rd_tipo_1}>+\frac<{M2}><{M_Rd_tipo_3}>\right) \leq 1.0$$

\vspace<0.3cm>

$${N_Sd_N_Rd}/2+ \left({M_xSd_M_xRd}+{M_ySd_M_yRd}\right) \leq 1.0$$

\vspace<0.3cm>

$${Verificação_PMM} \leq 1.0$$
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CG= np.where ( (M3 < -0.1) | (M3 > 0.1) | (M2 < -0.1) | (M2 > 0.1) , 
                                np.where ( Verificação_PMM <= 1 , rf"""

O perfil está apto para resistir aos esforços solicitantes combinados.\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CH= np.where ( (M3 < -0.1) | (M3 > 0.1) | (M2 < -0.1) | (M2 > 0.1) ,
                                np.where ( Verificação_PMM > 1 , rf"""

O perfil não está apta para resistir aos esforços solicitantes combinados.\\
\\
\vspace<0.3cm>
\\


""" ,
"""   """).item()
,
"""   """).item()
   
    latex_content_trecho_CI= np.where ( (V3 < -0.1) | (V3 > 0.1) | (V2 < -0.1) | (V2 > 0.1) , rf"""

\subsection<Verificação dos Esforços Cortantes>
Conforme item 5.5.1.3 da NBR8800:2024, os casos onde a força cortante atuante na direção de um dos eixos centrais de inércia,
a verificação da barra a esse esforço deve ser feita conforme 5.4.3 da NBR8800:2024. Esta verificaçao foi apresentada nos item 
intitulados "Força Cortante Resistente de Cálculo" deste documento.\\
Conforme item 5.4.1.3 da NBR8800:2024, o dimensionamento das barras submetidas a força cortante, deve ser
atendida a seguinte condição:\\
$$V_<Sd> \leq V_<Rd>$$
\\
Onde:\\
$V_<Sd>$ é a força cortante solicitante de cálculo;\\
$V_<Rd>$ é a força cortante resistente de cálculo, determinada conforme 5.4.3.\\
\\
\\

""",
"""   """).item()

    latex_content_trecho_CJ= np.where ( (V2 < -0.1) | (V2 > 0.1) , rf"""

Sendo assim, $V_<y,Sd> = {V2}$ e $V_<y,Rd> = {V_Rd_vert}$ são os esforços cortantes que atuam na direção paralela a alma do perfil.\\
\vspace<0.3cm>
\\

""",
"""   """).item()

    latex_content_trecho_CK= np.where ( (V2 < -0.1) | (V2 > 0.1) , 
                                np.where ( V_Sd_V_Rd_vert <= 1 , rf"""

A relação $V_<y,Sd> \leq V_<y,Rd>$ é atendida e a taxa de aproveitamento do perfil (razão $V_<y,Sd> / V_<y,Rd>$) é igual a {V_Sd_V_Rd_vert}.\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CL= np.where ( (V2 < -0.1) | (V2 > 0.1) , 
                                np.where ( V_Sd_V_Rd_vert > 1 , rf"""

A relação $V_<y,Sd> \leq V_<y,Rd>$ não é atendida e a taxa de aproveitamento do perfil (razão $V_<y,Sd> / V_<y,Rd>$) é igual a {V_Sd_V_Rd_vert}.\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CM= np.where ( (V3 < -0.1) | (V3 > 0.1) , rf"""

Sendo assim, $V_<x,Sd> = {V3}$ e $V_<x,Rd> = {V_Rd_horz}$ são os esforços cortantes que atuam na direção transversal a alma do perfil.\\
\vspace<0.3cm>
\\

""",
"""   """).item()

    latex_content_trecho_CN= np.where ( (V3 < -0.1) | (V3 > 0.1) ,
                                np.where ( V_Sd_V_Rd_horz <= 1 , rf"""

A relação $V_<x,Sd> \leq V_<x,Rd>$ é atendida e a taxa de aproveitamento do perfil (razão $V_<x,Sd> / V_<x,Rd>$) é igual a {V_Sd_V_Rd_horz}.\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CO= np.where ( (V3 < -0.1) | (V3 > 0.1) ,
                                np.where ( V_Sd_V_Rd_horz > 1 , rf"""

A relação $V_<x,Sd> \leq V_<x,Rd>$ não é atendida e a taxa de aproveitamento do perfil (razão $V_<x,Sd> / V_<x,Rd>$) é igual a {V_Sd_V_Rd_horz}.\\
\\
\\
""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CP= rf"""

\section<Conclusão>
O perfil metálico chamado \textit<{Frame}>, a qual foi adotada a seção \textit<{SectionName}>, e na posição {Station}m encontra-se:\\
\\

\begin<enumerate>[label=\alph*), leftmargin=1.5cm]

"""

    latex_content_trecho_CPA= np.where ( ((M3 >= -0.1) & (M3 <= 0.1)) & ((M2 >= -0.1) & (M2 <= 0.1)) ,
                                 np.where ( N_Sd_N_Rd <= 1, rf"""
                                        
\item APTO a resistir os esforços axiais simples, conforme detalhado no item intitulado "Verificação Esforço Axial Simples";\\

""" ,
"""   """).item()    
,
"""   """).item()     

    latex_content_trecho_CPB= np.where ( ((M3 >= -0.1) & (M3 <= 0.1)) & ((M2 >= -0.1) & (M2 <= 0.1)) ,
                                 np.where ( N_Sd_N_Rd > 1, rf"""
                                        
\item NÂO APTO a resistir os esforços axiais simples, conforme detalhado no item intitulado "Verificação Esforço Axial Simples";\\

""" ,
"""   """).item()    
,
"""   """).item()                               

    latex_content_trecho_CQ= np.where ( (M3 < -0.1) | (M3 > 0.1) | (M2 < -0.1) | (M2 > 0.1) , 
                                np.where ( Verificação_PMM <= 1 , rf"""

\item APTO a resistir os esforços axiais e esforços de flexão nas duas direções, conforme detalhado no 
item intitulado "Verificação da Combinação Esforço Axial - Flexão Principal - Flexão Secundária";\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CR= np.where ( (M3 < -0.1) | (M3 > 0.1) | (M2 < -0.1) | (M2 > 0.1) ,
                                np.where ( Verificação_PMM > 1 , rf"""

\item NÃO APTO a resistir os esforços axiais e esforços de flexão nas duas direções, conforme detalhado no 
item intitulado "Verificação da Combinação Esforço Axial - Flexão Principal - Flexão Secundária";\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CS= np.where ( (V2 < -0.1) | (V2 > 0.1) ,
                                np.where ( V_Sd_V_Rd_vert <= 1 , rf"""

\item APTO a resistir os esforços cortantes na direção de flexão no eixo de maior inercia (direção paralela 
a alma do perfil), conforme detalhado no item intitulado "Verificação dos Esforços Cortantes";\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CT= np.where ( (V2 < -0.1) | (V2 > 0.1) ,
                                np.where ( V_Sd_V_Rd_vert > 1 , rf"""

\item NÃO APTO a resistir os esforços cortantes na direção de flexão no eixo de maior inercia (direção paralela 
a alma do perfil), conforme detalhado no item intitulado "Verificação dos Esforços Cortantes";\\
\\

""" ,
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CU= np.where ( (V3 < -0.1) | (V3 > 0.1) ,
                                np.where ( V_Sd_V_Rd_horz <= 1 , rf"""
\item APTO a resistir os esforços cortantes na direção de flexão no eixo de menor inercia (direção paralela 
as mesas do perfil), conforme detalhado no item intitulado "Verificação dos Esforços Cortantes";\\
\\

""" , 
"""   """).item()
,
"""   """).item()

    latex_content_trecho_CV= np.where ( (V3 < -0.1) | (V3 > 0.1) ,
                                np.where ( V_Sd_V_Rd_horz > 1 , rf"""
\item NÃO APTO a resistir os esforços cortantes na direção de flexão no eixo de menor inercia (direção paralela 
as mesas do perfil), conforme detalhado no item intitulado "Verificação dos Esforços Cortantes";\\
\\

""" ,
"""   """).item()
,
"""   """).item()
    
    latex_content_trecho_CW=  rf"""

\end<enumerate>

\end<document>

""" 


    # Somar as strings do trecho_A até o trecho_CV
    latex_content = ( latex_content_trecho_A + 
                      latex_content_trecho_B + 
                      latex_content_trecho_C + 
                      latex_content_trecho_D + 
                      latex_content_trecho_E + 
                      latex_content_trecho_F + 
                      latex_content_trecho_G + 
                      latex_content_trecho_H + 
                      latex_content_trecho_I + 
                      latex_content_trecho_J + 
                      latex_content_trecho_K + 
                      latex_content_trecho_L + 
                      latex_content_trecho_M + 
                      latex_content_trecho_N + 
                      latex_content_trecho_O + 
                      latex_content_trecho_P + 
                      latex_content_trecho_Q + 
                      latex_content_trecho_R + 
                      latex_content_trecho_S + 
                      latex_content_trecho_T + 
                      latex_content_trecho_U + 
                      latex_content_trecho_V + 
                      latex_content_trecho_W + 
                      latex_content_trecho_X + 
                      latex_content_trecho_Y + 
                      latex_content_trecho_Z + 
                      latex_content_trecho_AA + 
                      latex_content_trecho_AB + 
                      latex_content_trecho_AC + 
                      latex_content_trecho_AD + 
                      latex_content_trecho_AE + 
                      latex_content_trecho_AF + 
                      latex_content_trecho_AG + 
                      latex_content_trecho_AH + 
                      latex_content_trecho_AI + 
                      latex_content_trecho_AJ + 
                      latex_content_trecho_AK + 
                      latex_content_trecho_AL + 
                      latex_content_trecho_AM + 
                      latex_content_trecho_AN + 
                      latex_content_trecho_AO + 
                      latex_content_trecho_AP + 
                      latex_content_trecho_AQ + 
                      latex_content_trecho_AR + 
                      latex_content_trecho_AS + 
                      latex_content_trecho_AT + 
                      latex_content_trecho_AU + 
                      latex_content_trecho_AV + 
                      latex_content_trecho_AW + 
                      latex_content_trecho_AX + 
                      latex_content_trecho_AY + 
                      latex_content_trecho_AZ + 
                      latex_content_trecho_BA + 
                      latex_content_trecho_BB + 
                      latex_content_trecho_BC + 
                      latex_content_trecho_BD + 
                      latex_content_trecho_BE + 
                      latex_content_trecho_BF + 
                      latex_content_trecho_BG + 
                      latex_content_trecho_BH + 
                      latex_content_trecho_BI + 
                      latex_content_trecho_BJ + 
                      latex_content_trecho_BK + 
                      latex_content_trecho_BL + 
                      latex_content_trecho_BM + 
                      latex_content_trecho_BN + 
                      latex_content_trecho_BO + 
                      latex_content_trecho_BP + 
                      latex_content_trecho_BQ + 
                      latex_content_trecho_BR + 
                      latex_content_trecho_BS + 
                      latex_content_trecho_BT + 
                      latex_content_trecho_BU + 
                      latex_content_trecho_BV + 
                      latex_content_trecho_BX + 
                      latex_content_trecho_BY +
                      latex_content_trecho_BZ + 
                      latex_content_trecho_CA + 
                      latex_content_trecho_CB + 
                      latex_content_trecho_CC + 
                      latex_content_trecho_CD + 
                      latex_content_trecho_CDA + 
                      latex_content_trecho_CE + 
                      latex_content_trecho_CF + 
                      latex_content_trecho_CG +  
                      latex_content_trecho_CI + 
                      latex_content_trecho_CJ + 
                      latex_content_trecho_CK + 
                      latex_content_trecho_CL + 
                      latex_content_trecho_CM + 
                      latex_content_trecho_CN + 
                      latex_content_trecho_CO + 
                      latex_content_trecho_CP + 
                      latex_content_trecho_CPA +
                      latex_content_trecho_CPB +
                      latex_content_trecho_CQ + 
                      latex_content_trecho_CR + 
                      latex_content_trecho_CS + 
                      latex_content_trecho_CT + 
                      latex_content_trecho_CU + 
                      latex_content_trecho_CV +
                      latex_content_trecho_CW )



    # Substituir "<" por "{" e ">" por "}"
    latex_content = latex_content.replace("<", "{").replace(">", "}")

    # Passo 5: Gerar o nome do arquivo com o número da linha
    nome_arquivo = f"resultado_linha_{linha_escolhida + 2:05d}-barra_{Frame}-combinação_{Combo}.tex"

    # Passo 6: Salvar o arquivo LaTeX
    with open(nome_arquivo, "w", encoding="utf-8") as f:
        f.write(latex_content)

    print(f"Arquivo LaTeX '{nome_arquivo}' gerado com sucesso!")
# Out:
# Arquivo LaTeX 'resultado_linha_00161-barra_PM-009-combinação_ELU 001.tex' gerado com sucesso!
# Arquivo LaTeX 'resultado_linha_01161-barra_VM-005-combinação_ELU 001.tex' gerado com sucesso!
# Arquivo LaTeX 'resultado_linha_01353-barra_VM-006-combinação_ELU 001.tex' gerado com sucesso!
# Saindo do programa. Até logo!
